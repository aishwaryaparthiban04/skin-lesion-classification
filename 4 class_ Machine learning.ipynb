# %%
import numpy as np 
import matplotlib.pyplot as plt
import glob
import cv2
import os
import seaborn as sns
import pandas as pd
from skimage.io import imshow, imread
from skimage.color import rgb2gray
from skimage.feature import hog
from sklearn.model_selection import train_test_split
import shutil
from tensorflow.keras.models import load_model
from sklearn.metrics import classification_report, confusion_matrix
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('HAM10000_metadata',sep=',')
df.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization  \
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
#
#         dataset
# 0  vidir_modern
# 1  vidir_modern
# 2  vidir_modern
# 3  vidir_modern
# 4  vidir_modern

# %%
df['dx'].value_counts()
# Out:
# nv       6705
# mel      1113
# bkl      1099
# bcc       514
# akiec     327
# vasc      142
# df        115
# Name: dx, dtype: int64

# %%
df.shape
# Out:
# (10015, 8)

# %%
dataset_default_path = 'HAM10000_images_part_1'
train_set_path = 'dataset/train'
test_set_path = 'dataset/test'
min_samples = 200
rand_seed = 0

# %%
df_nv = df[df.dx=='nv']
df_mel = df[df.dx=='mel']
df_bkl = df[df.dx=='bkl']
df_bcc = df[df.dx=='bcc']

# %%
df_nv=df_nv.head(1000)

# %%
df_nv.shape
# Out:
# (1000, 8)

# %%
data =df_mel.append(df_nv, ignore_index=True)

# %%
data1= data.append(df_bkl,ignore_index=True)

df= data1.append(df_bcc,ignore_index=True)

# %%
df.head()
# Out:
#      lesion_id      image_id   dx dx_type   age     sex     localization  \
# 0  HAM_0000871  ISIC_0025964  mel   histo  40.0  female            chest
# 1  HAM_0000871  ISIC_0030623  mel   histo  40.0  female            chest
# 2  HAM_0000040  ISIC_0027190  mel   histo  80.0    male  upper extremity
# 3  HAM_0005678  ISIC_0031023  mel   histo  60.0    male            chest
# 4  HAM_0005678  ISIC_0028086  mel   histo  60.0    male            chest
#
#         dataset
# 0  vidir_modern
# 1  vidir_modern
# 2     rosendahl
# 3  vidir_modern
# 4  vidir_modern

# %%
df.shape
# Out:
# (3726, 8)

# %%
df.dx.value_counts()
# Out:
# mel    1113
# bkl    1099
# nv     1000
# bcc     514
# Name: dx, dtype: int64

# %%
sns.countplot(df['dx'])
# Out:
# <AxesSubplot:xlabel='dx', ylabel='count'>

# %%
plt.hist(df['age'], bins = 15)
sns.set_theme()
plt.title('Histogram distribution of age')
# Out:
# Text(0.5, 1.0, 'Histogram distribution of age')

# %% [markdown]
# # Pixel values distribution an image

# %%
# Plot a histogram of the bkl class

raw_image = plt.imread('images_data/ISIC_0028977.jpg')


sns.distplot(raw_image.ravel(), 
             label=f'Pixel Mean {np.mean(raw_image):.4f} & Standard Deviation {np.std(raw_image):.4f}', kde=False)
plt.legend(loc='upper center')
plt.title('Distribution of Pixel Intensities in the Image')
plt.xlabel('Pixel Intensity')
plt.ylabel('# Pixels in Image')
# Out:
# Text(0, 0.5, '# Pixels in Image')

# %%
raw_image = plt.imread('images_data/ISIC_0026208.jpg')


sns.distplot(raw_image.ravel(), 
             label=f'Pixel Mean {np.mean(raw_image):.4f} & Standard Deviation {np.std(raw_image):.4f}', kde=False)
plt.legend(loc='upper center')
plt.title('Distribution of Pixel Intensities in the Image')
plt.xlabel('Pixel Intensity')
plt.ylabel('# Pixels in Image')
# Out:
# C:\Users\Abhishek\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, '# Pixels in Image')

# %%
raw_image = plt.imread('images_data/ISIC_0033534.jpg')


sns.distplot(raw_image.ravel(), 
             label=f'Pixel Mean {np.mean(raw_image):.4f} & Standard Deviation {np.std(raw_image):.4f}', kde=False)
plt.legend(loc='upper center')
plt.title('Distribution of Pixel Intensities in the Image')
plt.xlabel('Pixel Intensity')
plt.ylabel('# Pixels in Image')
# Out:
# Text(0, 0.5, '# Pixels in Image')

# %%
raw_image = plt.imread('images_data/ISIC_0026528.jpg')

sns.distplot(raw_image.ravel(), 
             label=f'Pixel Mean {np.mean(raw_image):.4f} & Standard Deviation {np.std(raw_image):.4f}', kde=False)
plt.legend(loc='upper center')
plt.title('Distribution of Pixel Intensities in the Image')
plt.xlabel('Pixel Intensity')
plt.ylabel('# Pixels in Image')
# Out:
# Text(0, 0.5, '# Pixels in Image')

# %%
df.to_csv('main_data.csv')

# %%
df.shape
# Out:
# (3726, 8)

# %%
def build_train_test(num_samples=0, train_set_frac=0.75, dataset_path=dataset_default_path,
                     train_path=train_set_path, test_path=test_set_path,
                     overwrite=False):


    if not os.path.isdir(dataset_path):
        dataset_path = dataset_default_path
    
    abs_dataset_path = os.path.abspath(dataset_path)

    if not os.path.isdir(train_path):
        train_path = train_set_path
    
    abs_train_path = os.path.abspath(train_path)
    if overwrite:
        shutil.rmtree(abs_train_path)
        os.mkdir(abs_train_path)

    if not os.path.isdir(test_path):
        test_path = test_set_path
    
    abs_test_path = os.path.abspath(test_path)
    if overwrite:
        shutil.rmtree(abs_test_path)
        os.mkdir(abs_test_path)

        
    ham10000_df = pd.read_csv('main_data.csv',sep=',')
    

    for img_idx in range(ham10000_df['image_id'].count()):
        ham10000_df.at[img_idx, 'image_id'] += '.jpg'

    classes = list(set(ham10000_df.dx))
    num_images = ham10000_df.image_id.count()

    if 0 < num_samples < min_samples:
        ham10000_df = ham10000_df.sample(n=min_samples, random_state=rand_seed)        
    elif num_samples > num_images:
        print('Warning')
        
    elif min_samples <= num_samples <= num_images:
        ham10000_df = ham10000_df.sample(n=num_samples, random_state=rand_seed)


    print(ham10000_df.dx.value_counts())

    if train_set_frac < 0 or train_set_frac > 1.0:
        test_set_frac = 0.75


    train_set, test_set = train_test_split(ham10000_df, train_size=train_set_frac,
                                           random_state=rand_seed,
                                           stratify=ham10000_df.dx)


    train_imgs = list(train_set['image_id'])
    test_imgs = list(test_set['image_id'])

    for img_name in train_imgs:
        src_path = os.path.join(abs_dataset_path, img_name)
        shutil.copy2(src_path, abs_train_path)

    for img_name in test_imgs:
        src_path = os.path.join(abs_dataset_path, img_name)
        shutil.copy2(src_path, abs_test_path)
  
    return train_set, test_set, classes

# %% [markdown]
# # Labels description
#
#
#
# * basal cell carcinoma (bcc),
# * benign keratosis-like lesions (solar lentigines / seborrheic keratoses and lichen-planus like keratoses, bkl),
# * melanoma (mel),
# * melanocytic nevi (nv)

# %%
train_df, test_df, class_labels = build_train_test(num_samples=3726,
                                                   overwrite=True)
# Out:
# Class labels: ['bcc', 'bkl', 'mel', 'nv']
# Number of images in the HAM10000 dataset: 3726
# Number of images in the reduced dataset: 3726
# Number of images for each class (dataset):
# mel    1113
# bkl    1099
# nv     1000
# bcc     514
# Name: dx, dtype: int64
#
# Number of images in the training set : 2794
# Number of images for each class (training set):
# mel    835
# bkl    824
# nv     750
# bcc    385
# Name: dx, dtype: int64
#
# Number of images in the test set : 932
# Number of images for each class (test set):
# mel    278
# bkl    275
# nv     250
# bcc    129
# Name: dx, dtype: int64

# %%
main_data =train_df.append(test_df, ignore_index=True)

# %%
main_data.head()
# Out:
#    Unnamed: 0    lesion_id          image_id   dx    dx_type   age     sex  \
# 0        3208  HAM_0006159  ISIC_0028977.jpg  bkl  consensus  50.0  female
# 1        1984  HAM_0007201  ISIC_0026208.jpg   nv  follow_up  50.0    male
# 2        2550  HAM_0004889  ISIC_0028511.jpg  bkl      histo  75.0    male
# 3        1334  HAM_0003302  ISIC_0032434.jpg   nv  follow_up  70.0    male
# 4         643  HAM_0005953  ISIC_0033534.jpg  mel      histo  35.0  female
#
#       localization        dataset
# 0  upper extremity   vidir_modern
# 1  lower extremity  vidir_molemax
# 2  upper extremity      rosendahl
# 3  lower extremity  vidir_molemax
# 4  upper extremity   vidir_modern

# %%
from skimage.feature import hog
from skimage import data, exposure
from skimage.io import imread, imshow

image = imread("HAM10000_images_part_1\ISIC_0024306.jpg")

fd, hog_image = hog(image, orientations=8, pixels_per_cell=(16, 16),
                    cells_per_block=(1, 1), visualize=True, multichannel=True)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6), sharex=True, sharey=True)

ax1.axis('off')
ax1.imshow(image, cmap=plt.cm.gray)
ax1.set_title('Input image')

# Rescale histogram for better display
hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 10))

ax2.axis('off')
ax2.imshow(hog_image_rescaled, cmap=plt.cm.gray)
ax2.set_title('Histogram of Oriented Gradients')
plt.show()

# %%
main_data.head()
# Out:
#    Unnamed: 0    lesion_id          image_id   dx    dx_type   age     sex  \
# 0        3208  HAM_0006159  ISIC_0028977.jpg  bkl  consensus  50.0  female
# 1        1984  HAM_0007201  ISIC_0026208.jpg   nv  follow_up  50.0    male
# 2        2550  HAM_0004889  ISIC_0028511.jpg  bkl      histo  75.0    male
# 3        1334  HAM_0003302  ISIC_0032434.jpg   nv  follow_up  70.0    male
# 4         643  HAM_0005953  ISIC_0033534.jpg  mel      histo  35.0  female
#
#       localization        dataset
# 0  upper extremity   vidir_modern
# 1  lower extremity  vidir_molemax
# 2  upper extremity      rosendahl
# 3  lower extremity  vidir_molemax
# 4  upper extremity   vidir_modern

# %%
import os
import shutil

source_folder = 'dataset/train/'
destination_folder = 'images_data/'
 
allfiles = os.listdir(source_folder)
 
for f in allfiles:
    os.rename(source_folder + f, destination_folder + f)

# %%
source_folder = 'dataset/test/'
destination_folder = 'images_data/'
 
allfiles = os.listdir(source_folder)
 
for f in allfiles:
    os.rename(source_folder + f, destination_folder + f)

# %%
def hair_remove(image):
    # convert image to grayScale
    grayScale = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    
    # kernel for morphologyEx
    kernel = cv2.getStructuringElement(1,(17,17))
    
    # apply MORPH_BLACKHAT to grayScale image
    blackhat = cv2.morphologyEx(grayScale, cv2.MORPH_BLACKHAT, kernel)
    
    # apply thresholding to blackhat
    _,threshold = cv2.threshold(blackhat,10,255,cv2.THRESH_BINARY)
    
    # inpaint with original image and threshold image
    final_image = cv2.inpaint(image,threshold,1,cv2.INPAINT_TELEA)

    return final_image

# %%
from skimage.feature import hog

images = []
labels=[]

SIZE = 256

for directory_path in glob.glob("images_data//"):
    for img_path,j in zip(glob.glob(os.path.join(directory_path, "*.jpg")), os.listdir("images_data/")):   
        print(img_path)
        img = cv2.imread(img_path) #Reading color images
        img = cv2.resize(img, (SIZE, SIZE)) #Resize images
        img = hair_remove(img)
        img = hog(img,orientations=9,pixels_per_cell=(8,8),visualize=False,cells_per_block=(3,3),channel_axis=-1)
        images.append(img)
        labels.append(main_data.loc[main_data['image_id'] == j, 'dx'].iloc[0])
# Out:
# images_data\ISIC_0024309.jpg
# images_data\ISIC_0024310.jpg
# images_data\ISIC_0024312.jpg
# images_data\ISIC_0024313.jpg
# images_data\ISIC_0024315.jpg
# images_data\ISIC_0024322.jpg
# images_data\ISIC_0024323.jpg
# images_data\ISIC_0024324.jpg
# images_data\ISIC_0024327.jpg
# images_data\ISIC_0024331.jpg
# images_data\ISIC_0024332.jpg
# images_data\ISIC_0024333.jpg
# images_data\ISIC_0024336.jpg
# images_data\ISIC_0024337.jpg
# images_data\ISIC_0024338.jpg
# images_data\ISIC_0024345.jpg
# images_data\ISIC_0024346.jpg
# images_data\ISIC_0024348.jpg
# images_data\ISIC_0024351.jpg
# images_data\ISIC_0024357.jpg
# images_data\ISIC_0024358.jpg
# images_data\ISIC_0024360.jpg
# images_data\ISIC_0024364.jpg
# images_data\ISIC_0024365.jpg
# images_data\ISIC_0024367.jpg
# images_data\ISIC_0024369.jpg
# images_data\ISIC_0024371.jpg
# images_data\ISIC_0024374.jpg
# images_data\ISIC_0024376.jpg
# images_data\ISIC_0024379.jpg
# images_data\ISIC_0024381.jpg
# images_data\ISIC_0024382.jpg
# images_data\ISIC_0024383.jpg
# images_data\ISIC_0024392.jpg
# images_data\ISIC_0024400.jpg
# images_data\ISIC_0024403.jpg
# images_data\ISIC_0024404.jpg
# images_data\ISIC_0024407.jpg
# images_data\ISIC_0024408.jpg
# images_data\ISIC_0024409.jpg
# images_data\ISIC_0024410.jpg
# images_data\ISIC_0024411.jpg
# images_data\ISIC_0024412.jpg
# images_data\ISIC_0024415.jpg
# images_data\ISIC_0024420.jpg
# images_data\ISIC_0024421.jpg
# images_data\ISIC_0024422.jpg
# images_data\ISIC_0024426.jpg
# images_data\ISIC_0024429.jpg
# images_data\ISIC_0024431.jpg
# images_data\ISIC_0024432.jpg
# images_data\ISIC_0024433.jpg
# images_data\ISIC_0024435.jpg
# images_data\ISIC_0024436.jpg
# images_data\ISIC_0024443.jpg
# images_data\ISIC_0024445.jpg
# images_data\ISIC_0024446.jpg
# images_data\ISIC_0024448.jpg
# images_data\ISIC_0024449.jpg
# images_data\ISIC_0024452.jpg
# images_data\ISIC_0024453.jpg
# images_data\ISIC_0024454.jpg
# images_data\ISIC_0024457.jpg
# images_data\ISIC_0024459.jpg
# images_data\ISIC_0024461.jpg
# images_data\ISIC_0024462.jpg
# images_data\ISIC_0024464.jpg
# images_data\ISIC_0024465.jpg
# images_data\ISIC_0024471.jpg
# images_data\ISIC_0024472.jpg
# images_data\ISIC_0024473.jpg
# images_data\ISIC_0024474.jpg
# images_data\ISIC_0024477.jpg
# images_data\ISIC_0024481.jpg
# images_data\ISIC_0024482.jpg
# images_data\ISIC_0024489.jpg
# images_data\ISIC_0024490.jpg
# images_data\ISIC_0024492.jpg
# images_data\ISIC_0024493.jpg
# images_data\ISIC_0024494.jpg
# images_data\ISIC_0024495.jpg
# images_data\ISIC_0024496.jpg
# images_data\ISIC_0024498.jpg
# images_data\ISIC_0024501.jpg
# images_data\ISIC_0024504.jpg
# images_data\ISIC_0024505.jpg
# images_data\ISIC_0024510.jpg
# images_data\ISIC_0024512.jpg
# images_data\ISIC_0024515.jpg
# images_data\ISIC_0024516.jpg
# images_data\ISIC_0024523.jpg
# images_data\ISIC_0024525.jpg
# images_data\ISIC_0024534.jpg
# images_data\ISIC_0024535.jpg
# images_data\ISIC_0024537.jpg
# images_data\ISIC_0024544.jpg
# images_data\ISIC_0024545.jpg
# images_data\ISIC_0024546.jpg
# images_data\ISIC_0024547.jpg
# images_data\ISIC_0024548.jpg
# images_data\ISIC_0024550.jpg
# images_data\ISIC_0024552.jpg
# images_data\ISIC_0024554.jpg
# images_data\ISIC_0024555.jpg
# images_data\ISIC_0024556.jpg
# images_data\ISIC_0024563.jpg
# images_data\ISIC_0024564.jpg
# images_data\ISIC_0024571.jpg
# images_data\ISIC_0024572.jpg
# images_data\ISIC_0024573.jpg
# images_data\ISIC_0024580.jpg
# images_data\ISIC_0024581.jpg
# images_data\ISIC_0024582.jpg
# images_data\ISIC_0024584.jpg
# images_data\ISIC_0024585.jpg
# images_data\ISIC_0024586.jpg
# images_data\ISIC_0024590.jpg
# images_data\ISIC_0024592.jpg
# images_data\ISIC_0024593.jpg
# images_data\ISIC_0024595.jpg
# images_data\ISIC_0024598.jpg
# images_data\ISIC_0024602.jpg
# images_data\ISIC_0024612.jpg
# images_data\ISIC_0024623.jpg
# images_data\ISIC_0024624.jpg
# images_data\ISIC_0024626.jpg
# images_data\ISIC_0024630.jpg
# images_data\ISIC_0024632.jpg
# images_data\ISIC_0024634.jpg
# images_data\ISIC_0024635.jpg
# images_data\ISIC_0024636.jpg
# images_data\ISIC_0024637.jpg
# images_data\ISIC_0024640.jpg
# images_data\ISIC_0024641.jpg
# images_data\ISIC_0024643.jpg
# images_data\ISIC_0024644.jpg
# images_data\ISIC_0024647.jpg
# images_data\ISIC_0024649.jpg
# images_data\ISIC_0024652.jpg
# images_data\ISIC_0024661.jpg
# images_data\ISIC_0024663.jpg
# images_data\ISIC_0024665.jpg
# images_data\ISIC_0024666.jpg
# images_data\ISIC_0024672.jpg
# images_data\ISIC_0024673.jpg
# images_data\ISIC_0024675.jpg
# images_data\ISIC_0024676.jpg
# images_data\ISIC_0024679.jpg
# images_data\ISIC_0024687.jpg
# images_data\ISIC_0024688.jpg
# images_data\ISIC_0024690.jpg
# images_data\ISIC_0024692.jpg
# images_data\ISIC_0024693.jpg
# images_data\ISIC_0024696.jpg
# images_data\ISIC_0024698.jpg
# images_data\ISIC_0024700.jpg
# images_data\ISIC_0024701.jpg
# images_data\ISIC_0024702.jpg
# images_data\ISIC_0024705.jpg
# images_data\ISIC_0024708.jpg
# images_data\ISIC_0024709.jpg
# images_data\ISIC_0024711.jpg
# images_data\ISIC_0024726.jpg
# images_data\ISIC_0024729.jpg
# images_data\ISIC_0024732.jpg
# images_data\ISIC_0024733.jpg
# images_data\ISIC_0024738.jpg
# images_data\ISIC_0024739.jpg
# images_data\ISIC_0024740.jpg
# images_data\ISIC_0024741.jpg
# images_data\ISIC_0024743.jpg
# images_data\ISIC_0024744.jpg
# images_data\ISIC_0024746.jpg
# images_data\ISIC_0024748.jpg
# images_data\ISIC_0024756.jpg
# images_data\ISIC_0024758.jpg
# images_data\ISIC_0024760.jpg
# images_data\ISIC_0024761.jpg
# images_data\ISIC_0024765.jpg
# images_data\ISIC_0024767.jpg
# images_data\ISIC_0024770.jpg
# images_data\ISIC_0024772.jpg
# images_data\ISIC_0024773.jpg
# images_data\ISIC_0024774.jpg
# images_data\ISIC_0024776.jpg
# images_data\ISIC_0024782.jpg
# images_data\ISIC_0024786.jpg
# images_data\ISIC_0024787.jpg
# images_data\ISIC_0024788.jpg
# images_data\ISIC_0024791.jpg
# images_data\ISIC_0024792.jpg
# images_data\ISIC_0024795.jpg
# images_data\ISIC_0024799.jpg
# images_data\ISIC_0024803.jpg
# images_data\ISIC_0024804.jpg
# images_data\ISIC_0024805.jpg
# images_data\ISIC_0024806.jpg
# images_data\ISIC_0024814.jpg
# images_data\ISIC_0024815.jpg
# images_data\ISIC_0024816.jpg
# images_data\ISIC_0024822.jpg
# images_data\ISIC_0024823.jpg
# images_data\ISIC_0024825.jpg
# images_data\ISIC_0024828.jpg
# images_data\ISIC_0024829.jpg
# images_data\ISIC_0024832.jpg
# images_data\ISIC_0024833.jpg
# images_data\ISIC_0024835.jpg
# images_data\ISIC_0024838.jpg
# images_data\ISIC_0024839.jpg
# images_data\ISIC_0024848.jpg
# images_data\ISIC_0024850.jpg
# images_data\ISIC_0024851.jpg
# images_data\ISIC_0024853.jpg
# images_data\ISIC_0024856.jpg
# images_data\ISIC_0024860.jpg
# images_data\ISIC_0024861.jpg
# images_data\ISIC_0024863.jpg
# images_data\ISIC_0024864.jpg
# images_data\ISIC_0024865.jpg
# images_data\ISIC_0024868.jpg
# images_data\ISIC_0024871.jpg
# images_data\ISIC_0024872.jpg
# images_data\ISIC_0024875.jpg
# images_data\ISIC_0024877.jpg
# images_data\ISIC_0024879.jpg
# images_data\ISIC_0024880.jpg
# images_data\ISIC_0024881.jpg
# images_data\ISIC_0024883.jpg
# images_data\ISIC_0024884.jpg
# images_data\ISIC_0024885.jpg
# images_data\ISIC_0024886.jpg
# images_data\ISIC_0024887.jpg
# images_data\ISIC_0024890.jpg
# images_data\ISIC_0024893.jpg
# images_data\ISIC_0024896.jpg
# images_data\ISIC_0024897.jpg
# images_data\ISIC_0024898.jpg
# images_data\ISIC_0024900.jpg
# images_data\ISIC_0024901.jpg
# images_data\ISIC_0024909.jpg
# images_data\ISIC_0024910.jpg
# images_data\ISIC_0024911.jpg
# images_data\ISIC_0024915.jpg
# images_data\ISIC_0024918.jpg
# images_data\ISIC_0024929.jpg
# images_data\ISIC_0024930.jpg
# images_data\ISIC_0024931.jpg
# images_data\ISIC_0024932.jpg
# images_data\ISIC_0024940.jpg
# images_data\ISIC_0024943.jpg
# images_data\ISIC_0024944.jpg
# images_data\ISIC_0024945.jpg
# images_data\ISIC_0024947.jpg
# images_data\ISIC_0024949.jpg
# images_data\ISIC_0024951.jpg
# images_data\ISIC_0024952.jpg
# images_data\ISIC_0024958.jpg
# images_data\ISIC_0024961.jpg
# images_data\ISIC_0024962.jpg
# images_data\ISIC_0024964.jpg
# images_data\ISIC_0024967.jpg
# images_data\ISIC_0024968.jpg
# images_data\ISIC_0024970.jpg
# images_data\ISIC_0024971.jpg
# images_data\ISIC_0024972.jpg
# images_data\ISIC_0024976.jpg
# images_data\ISIC_0024979.jpg
# images_data\ISIC_0024980.jpg
# images_data\ISIC_0024981.jpg
# images_data\ISIC_0024982.jpg
# images_data\ISIC_0024984.jpg
# images_data\ISIC_0024985.jpg
# images_data\ISIC_0024987.jpg
# images_data\ISIC_0024989.jpg
# images_data\ISIC_0024997.jpg
# images_data\ISIC_0024999.jpg
# images_data\ISIC_0025003.jpg
# images_data\ISIC_0025005.jpg
# images_data\ISIC_0025016.jpg
# images_data\ISIC_0025018.jpg
# images_data\ISIC_0025019.jpg
# images_data\ISIC_0025024.jpg
# images_data\ISIC_0025028.jpg
# images_data\ISIC_0025030.jpg
# images_data\ISIC_0025031.jpg
# images_data\ISIC_0025032.jpg
# images_data\ISIC_0025033.jpg
# images_data\ISIC_0025035.jpg
# images_data\ISIC_0025038.jpg
# images_data\ISIC_0025040.jpg
# images_data\ISIC_0025041.jpg
# images_data\ISIC_0025044.jpg
# images_data\ISIC_0025046.jpg
# images_data\ISIC_0025052.jpg
# images_data\ISIC_0025053.jpg
# images_data\ISIC_0025054.jpg
# images_data\ISIC_0025056.jpg
# images_data\ISIC_0025057.jpg
# images_data\ISIC_0025063.jpg
# images_data\ISIC_0025064.jpg
# images_data\ISIC_0025066.jpg
# images_data\ISIC_0025068.jpg
# images_data\ISIC_0025075.jpg
# images_data\ISIC_0025076.jpg
# images_data\ISIC_0025079.jpg
# images_data\ISIC_0025080.jpg
# images_data\ISIC_0025081.jpg
# images_data\ISIC_0025082.jpg
# images_data\ISIC_0025083.jpg
# images_data\ISIC_0025084.jpg
# images_data\ISIC_0025085.jpg
# images_data\ISIC_0025086.jpg
# images_data\ISIC_0025090.jpg
# images_data\ISIC_0025093.jpg
# images_data\ISIC_0025095.jpg
# images_data\ISIC_0025097.jpg
# images_data\ISIC_0025099.jpg
# images_data\ISIC_0025102.jpg
# images_data\ISIC_0025103.jpg
# images_data\ISIC_0025104.jpg
# images_data\ISIC_0025105.jpg
# images_data\ISIC_0025109.jpg
# images_data\ISIC_0025113.jpg
# images_data\ISIC_0025116.jpg
# images_data\ISIC_0025120.jpg
# images_data\ISIC_0025121.jpg
# images_data\ISIC_0025127.jpg
# images_data\ISIC_0025128.jpg
# images_data\ISIC_0025131.jpg
# images_data\ISIC_0025132.jpg
# images_data\ISIC_0025136.jpg
# images_data\ISIC_0025140.jpg
# images_data\ISIC_0025142.jpg
# images_data\ISIC_0025143.jpg
# images_data\ISIC_0025144.jpg
# images_data\ISIC_0025145.jpg
# images_data\ISIC_0025146.jpg
# images_data\ISIC_0025150.jpg
# images_data\ISIC_0025153.jpg
# images_data\ISIC_0025155.jpg
# images_data\ISIC_0025157.jpg
# images_data\ISIC_0025161.jpg
# images_data\ISIC_0025175.jpg
# images_data\ISIC_0025180.jpg
# images_data\ISIC_0025188.jpg
# images_data\ISIC_0025192.jpg
# images_data\ISIC_0025195.jpg
# images_data\ISIC_0025199.jpg
# images_data\ISIC_0025201.jpg
# images_data\ISIC_0025205.jpg
# images_data\ISIC_0025206.jpg
# images_data\ISIC_0025209.jpg
# images_data\ISIC_0025213.jpg
# images_data\ISIC_0025218.jpg
# images_data\ISIC_0025219.jpg
# images_data\ISIC_0025221.jpg
# images_data\ISIC_0025222.jpg
# images_data\ISIC_0025224.jpg
# images_data\ISIC_0025234.jpg
# images_data\ISIC_0025235.jpg
# images_data\ISIC_0025238.jpg
# images_data\ISIC_0025246.jpg
# images_data\ISIC_0025248.jpg
# images_data\ISIC_0025251.jpg
# images_data\ISIC_0025255.jpg
# images_data\ISIC_0025256.jpg
# images_data\ISIC_0025260.jpg
# images_data\ISIC_0025265.jpg
# images_data\ISIC_0025266.jpg
# images_data\ISIC_0025268.jpg
# images_data\ISIC_0025274.jpg
# images_data\ISIC_0025275.jpg
# images_data\ISIC_0025276.jpg
# images_data\ISIC_0025277.jpg
# images_data\ISIC_0025285.jpg
# images_data\ISIC_0025286.jpg
# images_data\ISIC_0025287.jpg
# images_data\ISIC_0025292.jpg
# images_data\ISIC_0025297.jpg
# images_data\ISIC_0025298.jpg
# images_data\ISIC_0025299.jpg
# images_data\ISIC_0025301.jpg
# images_data\ISIC_0025303.jpg
# images_data\ISIC_0025311.jpg
# images_data\ISIC_0025312.jpg
# images_data\ISIC_0025313.jpg
# images_data\ISIC_0025316.jpg
# images_data\ISIC_0025317.jpg
# images_data\ISIC_0025318.jpg
# images_data\ISIC_0025320.jpg
# images_data\ISIC_0025322.jpg
# images_data\ISIC_0025324.jpg
# images_data\ISIC_0025325.jpg
# images_data\ISIC_0025326.jpg
# images_data\ISIC_0025328.jpg
# images_data\ISIC_0025330.jpg
# images_data\ISIC_0025337.jpg
# images_data\ISIC_0025338.jpg
# images_data\ISIC_0025339.jpg
# images_data\ISIC_0025345.jpg
# images_data\ISIC_0025351.jpg
# images_data\ISIC_0025353.jpg
# images_data\ISIC_0025359.jpg
# images_data\ISIC_0025362.jpg
# images_data\ISIC_0025363.jpg
# images_data\ISIC_0025364.jpg
# images_data\ISIC_0025365.jpg
# images_data\ISIC_0025366.jpg
# images_data\ISIC_0025374.jpg
# images_data\ISIC_0025375.jpg
# images_data\ISIC_0025376.jpg
# images_data\ISIC_0025378.jpg
# images_data\ISIC_0025383.jpg
# images_data\ISIC_0025384.jpg
# images_data\ISIC_0025387.jpg
# images_data\ISIC_0025388.jpg
# images_data\ISIC_0025389.jpg
# images_data\ISIC_0025390.jpg
# images_data\ISIC_0025391.jpg
# images_data\ISIC_0025392.jpg
# images_data\ISIC_0025394.jpg
# images_data\ISIC_0025397.jpg
# images_data\ISIC_0025398.jpg
# images_data\ISIC_0025406.jpg
# images_data\ISIC_0025407.jpg
# images_data\ISIC_0025409.jpg
# images_data\ISIC_0025413.jpg
# images_data\ISIC_0025414.jpg
# images_data\ISIC_0025415.jpg
# images_data\ISIC_0025416.jpg
# images_data\ISIC_0025417.jpg
# images_data\ISIC_0025419.jpg
# images_data\ISIC_0025431.jpg
# images_data\ISIC_0025432.jpg
# images_data\ISIC_0025433.jpg
# images_data\ISIC_0025434.jpg
# images_data\ISIC_0025439.jpg
# images_data\ISIC_0025444.jpg
# images_data\ISIC_0025450.jpg
# images_data\ISIC_0025451.jpg
# images_data\ISIC_0025454.jpg
# images_data\ISIC_0025457.jpg
# images_data\ISIC_0025461.jpg
# images_data\ISIC_0025465.jpg
# images_data\ISIC_0025466.jpg
# images_data\ISIC_0025467.jpg
# images_data\ISIC_0025470.jpg
# images_data\ISIC_0025472.jpg
# images_data\ISIC_0025474.jpg
# images_data\ISIC_0025482.jpg
# images_data\ISIC_0025484.jpg
# images_data\ISIC_0025485.jpg
# images_data\ISIC_0025487.jpg
# images_data\ISIC_0025489.jpg
# images_data\ISIC_0025500.jpg
# images_data\ISIC_0025501.jpg
# images_data\ISIC_0025507.jpg
# images_data\ISIC_0025508.jpg
# images_data\ISIC_0025509.jpg
# images_data\ISIC_0025510.jpg
# images_data\ISIC_0025512.jpg
# images_data\ISIC_0025513.jpg
# images_data\ISIC_0025514.jpg
# images_data\ISIC_0025515.jpg
# images_data\ISIC_0025519.jpg
# images_data\ISIC_0025520.jpg
# images_data\ISIC_0025524.jpg
# images_data\ISIC_0025526.jpg
# images_data\ISIC_0025527.jpg
# images_data\ISIC_0025528.jpg
# images_data\ISIC_0025529.jpg
# images_data\ISIC_0025530.jpg
# images_data\ISIC_0025531.jpg
# images_data\ISIC_0025536.jpg
# images_data\ISIC_0025543.jpg
# images_data\ISIC_0025544.jpg
# images_data\ISIC_0025546.jpg
# images_data\ISIC_0025548.jpg
# images_data\ISIC_0025550.jpg
# images_data\ISIC_0025551.jpg
# images_data\ISIC_0025554.jpg
# images_data\ISIC_0025557.jpg
# images_data\ISIC_0025558.jpg
# images_data\ISIC_0025559.jpg
# images_data\ISIC_0025564.jpg
# images_data\ISIC_0025567.jpg
# images_data\ISIC_0025573.jpg
# images_data\ISIC_0025575.jpg
# images_data\ISIC_0025576.jpg
# images_data\ISIC_0025583.jpg
# images_data\ISIC_0025584.jpg
# images_data\ISIC_0025585.jpg
# images_data\ISIC_0025589.jpg
# images_data\ISIC_0025592.jpg
# images_data\ISIC_0025593.jpg
# images_data\ISIC_0025600.jpg
# images_data\ISIC_0025601.jpg
# images_data\ISIC_0025603.jpg
# images_data\ISIC_0025607.jpg
# images_data\ISIC_0025611.jpg
# images_data\ISIC_0025613.jpg
# images_data\ISIC_0025615.jpg
# images_data\ISIC_0025616.jpg
# images_data\ISIC_0025617.jpg
# images_data\ISIC_0025623.jpg
# images_data\ISIC_0025627.jpg
# images_data\ISIC_0025630.jpg
# images_data\ISIC_0025634.jpg
# images_data\ISIC_0025635.jpg
# images_data\ISIC_0025636.jpg
# images_data\ISIC_0025642.jpg
# images_data\ISIC_0025644.jpg
# images_data\ISIC_0025650.jpg
# images_data\ISIC_0025651.jpg
# images_data\ISIC_0025654.jpg
# images_data\ISIC_0025656.jpg
# images_data\ISIC_0025659.jpg
# images_data\ISIC_0025661.jpg
# images_data\ISIC_0025663.jpg
# images_data\ISIC_0025664.jpg
# images_data\ISIC_0025674.jpg
# images_data\ISIC_0025675.jpg
# images_data\ISIC_0025676.jpg
# images_data\ISIC_0025678.jpg
# images_data\ISIC_0025691.jpg
# images_data\ISIC_0025692.jpg
# images_data\ISIC_0025693.jpg
# images_data\ISIC_0025699.jpg
# images_data\ISIC_0025700.jpg
# images_data\ISIC_0025703.jpg
# images_data\ISIC_0025708.jpg
# images_data\ISIC_0025709.jpg
# images_data\ISIC_0025710.jpg
# images_data\ISIC_0025711.jpg
# images_data\ISIC_0025716.jpg
# images_data\ISIC_0025718.jpg
# images_data\ISIC_0025719.jpg
# images_data\ISIC_0025722.jpg
# images_data\ISIC_0025723.jpg
# images_data\ISIC_0025724.jpg
# images_data\ISIC_0025731.jpg
# images_data\ISIC_0025732.jpg
# images_data\ISIC_0025738.jpg
# images_data\ISIC_0025740.jpg
# images_data\ISIC_0025743.jpg
# images_data\ISIC_0025744.jpg
# images_data\ISIC_0025746.jpg
# images_data\ISIC_0025747.jpg
# images_data\ISIC_0025748.jpg
# images_data\ISIC_0025749.jpg
# images_data\ISIC_0025751.jpg
# images_data\ISIC_0025752.jpg
# images_data\ISIC_0025753.jpg
# images_data\ISIC_0025755.jpg
# images_data\ISIC_0025756.jpg
# images_data\ISIC_0025758.jpg
# images_data\ISIC_0025766.jpg
# images_data\ISIC_0025767.jpg
# images_data\ISIC_0025775.jpg
# images_data\ISIC_0025777.jpg
# images_data\ISIC_0025781.jpg
# images_data\ISIC_0025783.jpg
# images_data\ISIC_0025791.jpg
# images_data\ISIC_0025793.jpg
# images_data\ISIC_0025794.jpg
# images_data\ISIC_0025799.jpg
# images_data\ISIC_0025800.jpg
# images_data\ISIC_0025804.jpg
# images_data\ISIC_0025805.jpg
# images_data\ISIC_0025806.jpg
# images_data\ISIC_0025810.jpg
# images_data\ISIC_0025813.jpg
# images_data\ISIC_0025814.jpg
# images_data\ISIC_0025815.jpg
# images_data\ISIC_0025818.jpg
# images_data\ISIC_0025819.jpg
# images_data\ISIC_0025822.jpg
# images_data\ISIC_0025824.jpg
# images_data\ISIC_0025826.jpg
# images_data\ISIC_0025830.jpg
# images_data\ISIC_0025832.jpg
# images_data\ISIC_0025833.jpg
# images_data\ISIC_0025835.jpg
# images_data\ISIC_0025837.jpg
# images_data\ISIC_0025838.jpg
# images_data\ISIC_0025842.jpg
# images_data\ISIC_0025843.jpg
# images_data\ISIC_0025849.jpg
# images_data\ISIC_0025851.jpg
# images_data\ISIC_0025856.jpg
# images_data\ISIC_0025861.jpg
# images_data\ISIC_0025866.jpg
# images_data\ISIC_0025867.jpg
# images_data\ISIC_0025868.jpg
# images_data\ISIC_0025874.jpg
# images_data\ISIC_0025876.jpg
# images_data\ISIC_0025877.jpg
# images_data\ISIC_0025878.jpg
# images_data\ISIC_0025879.jpg
# images_data\ISIC_0025883.jpg
# images_data\ISIC_0025885.jpg
# images_data\ISIC_0025891.jpg
# images_data\ISIC_0025900.jpg
# images_data\ISIC_0025904.jpg
# images_data\ISIC_0025906.jpg
# images_data\ISIC_0025910.jpg
# images_data\ISIC_0025914.jpg
# images_data\ISIC_0025915.jpg
# images_data\ISIC_0025922.jpg
# images_data\ISIC_0025927.jpg
# images_data\ISIC_0025928.jpg
# images_data\ISIC_0025929.jpg
# images_data\ISIC_0025930.jpg
# images_data\ISIC_0025931.jpg
# images_data\ISIC_0025932.jpg
# images_data\ISIC_0025934.jpg
# images_data\ISIC_0025937.jpg
# images_data\ISIC_0025939.jpg
# images_data\ISIC_0025940.jpg
# images_data\ISIC_0025941.jpg
# images_data\ISIC_0025947.jpg
# images_data\ISIC_0025952.jpg
# images_data\ISIC_0025955.jpg
# images_data\ISIC_0025963.jpg
# images_data\ISIC_0025964.jpg
# images_data\ISIC_0025966.jpg
# images_data\ISIC_0025971.jpg
# images_data\ISIC_0025973.jpg
# images_data\ISIC_0025974.jpg
# images_data\ISIC_0025975.jpg
# images_data\ISIC_0025979.jpg
# images_data\ISIC_0025981.jpg
# images_data\ISIC_0025982.jpg
# images_data\ISIC_0025984.jpg
# images_data\ISIC_0025985.jpg
# images_data\ISIC_0025986.jpg
# images_data\ISIC_0025987.jpg
# images_data\ISIC_0025994.jpg
# images_data\ISIC_0025996.jpg
# images_data\ISIC_0026009.jpg
# images_data\ISIC_0026011.jpg
# images_data\ISIC_0026015.jpg
# images_data\ISIC_0026016.jpg
# images_data\ISIC_0026018.jpg
# images_data\ISIC_0026021.jpg
# images_data\ISIC_0026032.jpg
# images_data\ISIC_0026036.jpg
# images_data\ISIC_0026038.jpg
# images_data\ISIC_0026039.jpg
# images_data\ISIC_0026042.jpg
# images_data\ISIC_0026044.jpg
# images_data\ISIC_0026045.jpg
# images_data\ISIC_0026046.jpg
# images_data\ISIC_0026051.jpg
# images_data\ISIC_0026054.jpg
# images_data\ISIC_0026056.jpg
# images_data\ISIC_0026057.jpg
# images_data\ISIC_0026060.jpg
# images_data\ISIC_0026069.jpg
# images_data\ISIC_0026070.jpg
# images_data\ISIC_0026072.jpg
# images_data\ISIC_0026074.jpg
# images_data\ISIC_0026075.jpg
# images_data\ISIC_0026079.jpg
# images_data\ISIC_0026081.jpg
# images_data\ISIC_0026085.jpg
# images_data\ISIC_0026086.jpg
# images_data\ISIC_0026087.jpg
# images_data\ISIC_0026089.jpg
# images_data\ISIC_0026090.jpg
# images_data\ISIC_0026091.jpg
# images_data\ISIC_0026094.jpg
# images_data\ISIC_0026098.jpg
# images_data\ISIC_0026104.jpg
# images_data\ISIC_0026105.jpg
# images_data\ISIC_0026107.jpg
# images_data\ISIC_0026112.jpg
# images_data\ISIC_0026113.jpg
# images_data\ISIC_0026114.jpg
# images_data\ISIC_0026115.jpg
# images_data\ISIC_0026117.jpg
# images_data\ISIC_0026118.jpg
# images_data\ISIC_0026120.jpg
# images_data\ISIC_0026128.jpg
# images_data\ISIC_0026129.jpg
# images_data\ISIC_0026131.jpg
# images_data\ISIC_0026135.jpg
# images_data\ISIC_0026136.jpg
# images_data\ISIC_0026137.jpg
# images_data\ISIC_0026139.jpg
# images_data\ISIC_0026142.jpg
# images_data\ISIC_0026144.jpg
# images_data\ISIC_0026145.jpg
# images_data\ISIC_0026150.jpg
# images_data\ISIC_0026153.jpg
# images_data\ISIC_0026154.jpg
# images_data\ISIC_0026156.jpg
# images_data\ISIC_0026158.jpg
# images_data\ISIC_0026159.jpg
# images_data\ISIC_0026167.jpg
# images_data\ISIC_0026168.jpg
# images_data\ISIC_0026169.jpg
# images_data\ISIC_0026172.jpg
# images_data\ISIC_0026173.jpg
# images_data\ISIC_0026174.jpg
# images_data\ISIC_0026175.jpg
# images_data\ISIC_0026185.jpg
# images_data\ISIC_0026188.jpg
# images_data\ISIC_0026192.jpg
# images_data\ISIC_0026201.jpg
# images_data\ISIC_0026202.jpg
# images_data\ISIC_0026205.jpg
# images_data\ISIC_0026207.jpg
# images_data\ISIC_0026208.jpg
# images_data\ISIC_0026211.jpg
# images_data\ISIC_0026213.jpg
# images_data\ISIC_0026214.jpg
# images_data\ISIC_0026219.jpg
# images_data\ISIC_0026225.jpg
# images_data\ISIC_0026227.jpg
# images_data\ISIC_0026229.jpg
# images_data\ISIC_0026230.jpg
# images_data\ISIC_0026232.jpg
# images_data\ISIC_0026234.jpg
# images_data\ISIC_0026236.jpg
# images_data\ISIC_0026239.jpg
# images_data\ISIC_0026241.jpg
# images_data\ISIC_0026242.jpg
# images_data\ISIC_0026243.jpg
# images_data\ISIC_0026245.jpg
# images_data\ISIC_0026246.jpg
# images_data\ISIC_0026247.jpg
# images_data\ISIC_0026248.jpg
# images_data\ISIC_0026249.jpg
# images_data\ISIC_0026255.jpg
# images_data\ISIC_0026256.jpg
# images_data\ISIC_0026258.jpg
# images_data\ISIC_0026262.jpg
# images_data\ISIC_0026263.jpg
# images_data\ISIC_0026265.jpg
# images_data\ISIC_0026266.jpg
# images_data\ISIC_0026267.jpg
# images_data\ISIC_0026268.jpg
# images_data\ISIC_0026269.jpg
# images_data\ISIC_0026273.jpg
# images_data\ISIC_0026275.jpg
# images_data\ISIC_0026276.jpg
# images_data\ISIC_0026277.jpg
# images_data\ISIC_0026280.jpg
# images_data\ISIC_0026281.jpg
# images_data\ISIC_0026282.jpg
# images_data\ISIC_0026283.jpg
# images_data\ISIC_0026286.jpg
# images_data\ISIC_0026290.jpg
# images_data\ISIC_0026291.jpg
# images_data\ISIC_0026292.jpg
# images_data\ISIC_0026296.jpg
# images_data\ISIC_0026298.jpg
# images_data\ISIC_0026301.jpg
# images_data\ISIC_0026302.jpg
# images_data\ISIC_0026311.jpg
# images_data\ISIC_0026314.jpg
# images_data\ISIC_0026316.jpg
# images_data\ISIC_0026320.jpg
# images_data\ISIC_0026321.jpg
# images_data\ISIC_0026324.jpg
# images_data\ISIC_0026335.jpg
# images_data\ISIC_0026337.jpg
# images_data\ISIC_0026339.jpg
# images_data\ISIC_0026343.jpg
# images_data\ISIC_0026350.jpg
# images_data\ISIC_0026351.jpg
# images_data\ISIC_0026352.jpg
# images_data\ISIC_0026355.jpg
# images_data\ISIC_0026360.jpg
# images_data\ISIC_0026361.jpg
# images_data\ISIC_0026364.jpg
# images_data\ISIC_0026365.jpg
# images_data\ISIC_0026366.jpg
# images_data\ISIC_0026369.jpg
# images_data\ISIC_0026378.jpg
# images_data\ISIC_0026383.jpg
# images_data\ISIC_0026395.jpg
# images_data\ISIC_0026399.jpg
# images_data\ISIC_0026409.jpg
# images_data\ISIC_0026415.jpg
# images_data\ISIC_0026416.jpg
# images_data\ISIC_0026420.jpg
# images_data\ISIC_0026422.jpg
# images_data\ISIC_0026425.jpg
# images_data\ISIC_0026430.jpg
# images_data\ISIC_0026433.jpg
# images_data\ISIC_0026435.jpg
# images_data\ISIC_0026438.jpg
# images_data\ISIC_0026439.jpg
# images_data\ISIC_0026441.jpg
# images_data\ISIC_0026442.jpg
# images_data\ISIC_0026443.jpg
# images_data\ISIC_0026444.jpg
# images_data\ISIC_0026446.jpg
# images_data\ISIC_0026449.jpg
# images_data\ISIC_0026453.jpg
# images_data\ISIC_0026458.jpg
# images_data\ISIC_0026460.jpg
# images_data\ISIC_0026465.jpg
# images_data\ISIC_0026470.jpg
# images_data\ISIC_0026475.jpg
# images_data\ISIC_0026476.jpg
# images_data\ISIC_0026477.jpg
# images_data\ISIC_0026481.jpg
# images_data\ISIC_0026489.jpg
# images_data\ISIC_0026493.jpg
# images_data\ISIC_0026496.jpg
# images_data\ISIC_0026500.jpg
# images_data\ISIC_0026506.jpg
# images_data\ISIC_0026511.jpg
# images_data\ISIC_0026514.jpg
# images_data\ISIC_0026515.jpg
# images_data\ISIC_0026516.jpg
# images_data\ISIC_0026518.jpg
# images_data\ISIC_0026520.jpg
# images_data\ISIC_0026523.jpg
# images_data\ISIC_0026524.jpg
# images_data\ISIC_0026526.jpg
# images_data\ISIC_0026528.jpg
# images_data\ISIC_0026529.jpg
# images_data\ISIC_0026530.jpg
# images_data\ISIC_0026531.jpg
# images_data\ISIC_0026532.jpg
# images_data\ISIC_0026533.jpg
# images_data\ISIC_0026538.jpg
# images_data\ISIC_0026539.jpg
# images_data\ISIC_0026540.jpg
# images_data\ISIC_0026545.jpg
# images_data\ISIC_0026553.jpg
# images_data\ISIC_0026555.jpg
# images_data\ISIC_0026556.jpg
# images_data\ISIC_0026557.jpg
# images_data\ISIC_0026558.jpg
# images_data\ISIC_0026562.jpg
# images_data\ISIC_0026565.jpg
# images_data\ISIC_0026566.jpg
# images_data\ISIC_0026567.jpg
# images_data\ISIC_0026571.jpg
# images_data\ISIC_0026574.jpg
# images_data\ISIC_0026576.jpg
# images_data\ISIC_0026583.jpg
# images_data\ISIC_0026585.jpg
# images_data\ISIC_0026586.jpg
# images_data\ISIC_0026590.jpg
# images_data\ISIC_0026593.jpg
# images_data\ISIC_0026594.jpg
# images_data\ISIC_0026596.jpg
# images_data\ISIC_0026604.jpg
# images_data\ISIC_0026606.jpg
# images_data\ISIC_0026607.jpg
# images_data\ISIC_0026613.jpg
# images_data\ISIC_0026614.jpg
# images_data\ISIC_0026620.jpg
# images_data\ISIC_0026621.jpg
# images_data\ISIC_0026622.jpg
# images_data\ISIC_0026623.jpg
# images_data\ISIC_0026631.jpg
# images_data\ISIC_0026634.jpg
# images_data\ISIC_0026637.jpg
# images_data\ISIC_0026641.jpg
# images_data\ISIC_0026643.jpg
# images_data\ISIC_0026644.jpg
# images_data\ISIC_0026647.jpg
# images_data\ISIC_0026651.jpg
# images_data\ISIC_0026652.jpg
# images_data\ISIC_0026656.jpg
# images_data\ISIC_0026659.jpg
# images_data\ISIC_0026661.jpg
# images_data\ISIC_0026663.jpg
# images_data\ISIC_0026664.jpg
# images_data\ISIC_0026668.jpg
# images_data\ISIC_0026675.jpg
# images_data\ISIC_0026679.jpg
# images_data\ISIC_0026681.jpg
# images_data\ISIC_0026682.jpg
# images_data\ISIC_0026687.jpg
# images_data\ISIC_0026689.jpg
# images_data\ISIC_0026690.jpg
# images_data\ISIC_0026694.jpg
# images_data\ISIC_0026696.jpg
# images_data\ISIC_0026697.jpg
# images_data\ISIC_0026700.jpg
# images_data\ISIC_0026704.jpg
# images_data\ISIC_0026710.jpg
# images_data\ISIC_0026714.jpg
# images_data\ISIC_0026715.jpg
# images_data\ISIC_0026716.jpg
# images_data\ISIC_0026717.jpg
# images_data\ISIC_0026718.jpg
# images_data\ISIC_0026728.jpg
# images_data\ISIC_0026731.jpg
# images_data\ISIC_0026733.jpg
# images_data\ISIC_0026735.jpg
# images_data\ISIC_0026737.jpg
# images_data\ISIC_0026738.jpg
# images_data\ISIC_0026740.jpg
# images_data\ISIC_0026744.jpg
# images_data\ISIC_0026745.jpg
# images_data\ISIC_0026746.jpg
# images_data\ISIC_0026754.jpg
# images_data\ISIC_0026755.jpg
# images_data\ISIC_0026760.jpg
# images_data\ISIC_0026766.jpg
# images_data\ISIC_0026768.jpg
# images_data\ISIC_0026769.jpg
# images_data\ISIC_0026770.jpg
# images_data\ISIC_0026773.jpg
# images_data\ISIC_0026774.jpg
# images_data\ISIC_0026775.jpg
# images_data\ISIC_0026778.jpg
# images_data\ISIC_0026780.jpg
# images_data\ISIC_0026783.jpg
# images_data\ISIC_0026787.jpg
# images_data\ISIC_0026790.jpg
# images_data\ISIC_0026792.jpg
# images_data\ISIC_0026794.jpg
# images_data\ISIC_0026796.jpg
# images_data\ISIC_0026798.jpg
# images_data\ISIC_0026802.jpg
# images_data\ISIC_0026803.jpg
# images_data\ISIC_0026806.jpg
# images_data\ISIC_0026811.jpg
# images_data\ISIC_0026812.jpg
# images_data\ISIC_0026814.jpg
# images_data\ISIC_0026817.jpg
# images_data\ISIC_0026822.jpg
# images_data\ISIC_0026823.jpg
# images_data\ISIC_0026824.jpg
# images_data\ISIC_0026827.jpg
# images_data\ISIC_0026829.jpg
# images_data\ISIC_0026830.jpg
# images_data\ISIC_0026831.jpg
# images_data\ISIC_0026835.jpg
# images_data\ISIC_0026836.jpg
# images_data\ISIC_0026842.jpg
# images_data\ISIC_0026843.jpg
# images_data\ISIC_0026844.jpg
# images_data\ISIC_0026845.jpg
# images_data\ISIC_0026846.jpg
# images_data\ISIC_0026847.jpg
# images_data\ISIC_0026849.jpg
# images_data\ISIC_0026853.jpg
# images_data\ISIC_0026854.jpg
# images_data\ISIC_0026855.jpg
# images_data\ISIC_0026858.jpg
# images_data\ISIC_0026861.jpg
# images_data\ISIC_0026862.jpg
# images_data\ISIC_0026865.jpg
# images_data\ISIC_0026867.jpg
# images_data\ISIC_0026868.jpg
# images_data\ISIC_0026870.jpg
# images_data\ISIC_0026871.jpg
# images_data\ISIC_0026875.jpg
# images_data\ISIC_0026877.jpg
# images_data\ISIC_0026891.jpg
# images_data\ISIC_0026892.jpg
# images_data\ISIC_0026893.jpg
# images_data\ISIC_0026895.jpg
# images_data\ISIC_0026897.jpg
# images_data\ISIC_0026902.jpg
# images_data\ISIC_0026907.jpg
# images_data\ISIC_0026909.jpg
# images_data\ISIC_0026910.jpg
# images_data\ISIC_0026912.jpg
# images_data\ISIC_0026914.jpg
# images_data\ISIC_0026915.jpg
# images_data\ISIC_0026916.jpg
# images_data\ISIC_0026920.jpg
# images_data\ISIC_0026923.jpg
# images_data\ISIC_0026928.jpg
# images_data\ISIC_0026929.jpg
# images_data\ISIC_0026930.jpg
# images_data\ISIC_0026936.jpg
# images_data\ISIC_0026940.jpg
# images_data\ISIC_0026941.jpg
# images_data\ISIC_0026947.jpg
# images_data\ISIC_0026948.jpg
# images_data\ISIC_0026949.jpg
# images_data\ISIC_0026950.jpg
# images_data\ISIC_0026952.jpg
# images_data\ISIC_0026954.jpg
# images_data\ISIC_0026955.jpg
# images_data\ISIC_0026957.jpg
# images_data\ISIC_0026958.jpg
# images_data\ISIC_0026959.jpg
# images_data\ISIC_0026960.jpg
# images_data\ISIC_0026961.jpg
# images_data\ISIC_0026963.jpg
# images_data\ISIC_0026967.jpg
# images_data\ISIC_0026968.jpg
# images_data\ISIC_0026970.jpg
# images_data\ISIC_0026976.jpg
# images_data\ISIC_0026978.jpg
# images_data\ISIC_0026980.jpg
# images_data\ISIC_0026986.jpg
# images_data\ISIC_0026988.jpg
# images_data\ISIC_0026989.jpg
# images_data\ISIC_0026993.jpg
# images_data\ISIC_0026994.jpg
# images_data\ISIC_0026995.jpg
# images_data\ISIC_0026996.jpg
# images_data\ISIC_0027000.jpg
# images_data\ISIC_0027004.jpg
# images_data\ISIC_0027006.jpg
# images_data\ISIC_0027017.jpg
# images_data\ISIC_0027018.jpg
# images_data\ISIC_0027019.jpg
# images_data\ISIC_0027021.jpg
# images_data\ISIC_0027023.jpg
# images_data\ISIC_0027025.jpg
# images_data\ISIC_0027026.jpg
# images_data\ISIC_0027027.jpg
# images_data\ISIC_0027030.jpg
# images_data\ISIC_0027033.jpg
# images_data\ISIC_0027037.jpg
# images_data\ISIC_0027038.jpg
# images_data\ISIC_0027041.jpg
# images_data\ISIC_0027042.jpg
# images_data\ISIC_0027043.jpg
# images_data\ISIC_0027046.jpg
# images_data\ISIC_0027053.jpg
# images_data\ISIC_0027055.jpg
# images_data\ISIC_0027057.jpg
# images_data\ISIC_0027058.jpg
# images_data\ISIC_0027060.jpg
# images_data\ISIC_0027061.jpg
# images_data\ISIC_0027063.jpg
# images_data\ISIC_0027064.jpg
# images_data\ISIC_0027065.jpg
# images_data\ISIC_0027067.jpg
# images_data\ISIC_0027068.jpg
# images_data\ISIC_0027069.jpg
# images_data\ISIC_0027071.jpg
# images_data\ISIC_0027076.jpg
# images_data\ISIC_0027082.jpg
# images_data\ISIC_0027083.jpg
# images_data\ISIC_0027085.jpg
# images_data\ISIC_0027089.jpg
# images_data\ISIC_0027090.jpg
# images_data\ISIC_0027093.jpg
# images_data\ISIC_0027094.jpg
# images_data\ISIC_0027100.jpg
# images_data\ISIC_0027101.jpg
# images_data\ISIC_0027102.jpg
# images_data\ISIC_0027105.jpg
# images_data\ISIC_0027106.jpg
# images_data\ISIC_0027108.jpg
# images_data\ISIC_0027110.jpg
# images_data\ISIC_0027111.jpg
# images_data\ISIC_0027117.jpg
# images_data\ISIC_0027120.jpg
# images_data\ISIC_0027121.jpg
# images_data\ISIC_0027124.jpg
# images_data\ISIC_0027125.jpg
# images_data\ISIC_0027126.jpg
# images_data\ISIC_0027130.jpg
# images_data\ISIC_0027135.jpg
# images_data\ISIC_0027136.jpg
# images_data\ISIC_0027139.jpg
# images_data\ISIC_0027142.jpg
# images_data\ISIC_0027144.jpg
# images_data\ISIC_0027145.jpg
# images_data\ISIC_0027146.jpg
# images_data\ISIC_0027149.jpg
# images_data\ISIC_0027151.jpg
# images_data\ISIC_0027154.jpg
# images_data\ISIC_0027155.jpg
# images_data\ISIC_0027156.jpg
# images_data\ISIC_0027157.jpg
# images_data\ISIC_0027160.jpg
# images_data\ISIC_0027162.jpg
# images_data\ISIC_0027163.jpg
# images_data\ISIC_0027164.jpg
# images_data\ISIC_0027165.jpg
# images_data\ISIC_0027166.jpg
# images_data\ISIC_0027167.jpg
# images_data\ISIC_0027170.jpg
# images_data\ISIC_0027171.jpg
# images_data\ISIC_0027174.jpg
# images_data\ISIC_0027175.jpg
# images_data\ISIC_0027179.jpg
# images_data\ISIC_0027187.jpg
# images_data\ISIC_0027189.jpg
# images_data\ISIC_0027190.jpg
# images_data\ISIC_0027192.jpg
# images_data\ISIC_0027194.jpg
# images_data\ISIC_0027195.jpg
# images_data\ISIC_0027202.jpg
# images_data\ISIC_0027204.jpg
# images_data\ISIC_0027212.jpg
# images_data\ISIC_0027215.jpg
# images_data\ISIC_0027218.jpg
# images_data\ISIC_0027219.jpg
# images_data\ISIC_0027220.jpg
# images_data\ISIC_0027221.jpg
# images_data\ISIC_0027227.jpg
# images_data\ISIC_0027229.jpg
# images_data\ISIC_0027234.jpg
# images_data\ISIC_0027238.jpg
# images_data\ISIC_0027239.jpg
# images_data\ISIC_0027251.jpg
# images_data\ISIC_0027253.jpg
# images_data\ISIC_0027260.jpg
# images_data\ISIC_0027261.jpg
# images_data\ISIC_0027263.jpg
# images_data\ISIC_0027268.jpg
# images_data\ISIC_0027270.jpg
# images_data\ISIC_0027275.jpg
# images_data\ISIC_0027276.jpg
# images_data\ISIC_0027277.jpg
# images_data\ISIC_0027278.jpg
# images_data\ISIC_0027279.jpg
# images_data\ISIC_0027281.jpg
# images_data\ISIC_0027282.jpg
# images_data\ISIC_0027283.jpg
# images_data\ISIC_0027287.jpg
# images_data\ISIC_0027290.jpg
# images_data\ISIC_0027291.jpg
# images_data\ISIC_0027295.jpg
# images_data\ISIC_0027297.jpg
# images_data\ISIC_0027300.jpg
# images_data\ISIC_0027301.jpg
# images_data\ISIC_0027302.jpg
# images_data\ISIC_0027306.jpg
# images_data\ISIC_0027307.jpg
# images_data\ISIC_0027309.jpg
# images_data\ISIC_0027310.jpg
# images_data\ISIC_0027315.jpg
# images_data\ISIC_0027316.jpg
# images_data\ISIC_0027318.jpg
# images_data\ISIC_0027320.jpg
# images_data\ISIC_0027324.jpg
# images_data\ISIC_0027326.jpg
# images_data\ISIC_0027327.jpg
# images_data\ISIC_0027328.jpg
# images_data\ISIC_0027331.jpg
# images_data\ISIC_0027332.jpg
# images_data\ISIC_0027333.jpg
# images_data\ISIC_0027335.jpg
# images_data\ISIC_0027337.jpg
# images_data\ISIC_0027339.jpg
# images_data\ISIC_0027344.jpg
# images_data\ISIC_0027347.jpg
# images_data\ISIC_0027350.jpg
# images_data\ISIC_0027352.jpg
# images_data\ISIC_0027354.jpg
# images_data\ISIC_0027355.jpg
# images_data\ISIC_0027356.jpg
# images_data\ISIC_0027359.jpg
# images_data\ISIC_0027365.jpg
# images_data\ISIC_0027367.jpg
# images_data\ISIC_0027370.jpg
# images_data\ISIC_0027371.jpg
# images_data\ISIC_0027373.jpg
# images_data\ISIC_0027374.jpg
# images_data\ISIC_0027375.jpg
# images_data\ISIC_0027384.jpg
# images_data\ISIC_0027387.jpg
# images_data\ISIC_0027388.jpg
# images_data\ISIC_0027389.jpg
# images_data\ISIC_0027392.jpg
# images_data\ISIC_0027394.jpg
# images_data\ISIC_0027400.jpg
# images_data\ISIC_0027402.jpg
# images_data\ISIC_0027405.jpg
# images_data\ISIC_0027407.jpg
# images_data\ISIC_0027411.jpg
# images_data\ISIC_0027416.jpg
# images_data\ISIC_0027419.jpg
# images_data\ISIC_0027420.jpg
# images_data\ISIC_0027422.jpg
# images_data\ISIC_0027425.jpg
# images_data\ISIC_0027426.jpg
# images_data\ISIC_0027428.jpg
# images_data\ISIC_0027429.jpg
# images_data\ISIC_0027433.jpg
# images_data\ISIC_0027435.jpg
# images_data\ISIC_0027436.jpg
# images_data\ISIC_0027437.jpg
# images_data\ISIC_0027440.jpg
# images_data\ISIC_0027442.jpg
# images_data\ISIC_0027451.jpg
# images_data\ISIC_0027454.jpg
# images_data\ISIC_0027455.jpg
# images_data\ISIC_0027456.jpg
# images_data\ISIC_0027463.jpg
# images_data\ISIC_0027467.jpg
# images_data\ISIC_0027470.jpg
# images_data\ISIC_0027472.jpg
# images_data\ISIC_0027473.jpg
# images_data\ISIC_0027478.jpg
# images_data\ISIC_0027479.jpg
# images_data\ISIC_0027480.jpg
# images_data\ISIC_0027482.jpg
# images_data\ISIC_0027485.jpg
# images_data\ISIC_0027487.jpg
# images_data\ISIC_0027502.jpg
# images_data\ISIC_0027504.jpg
# images_data\ISIC_0027507.jpg
# images_data\ISIC_0027509.jpg
# images_data\ISIC_0027513.jpg
# images_data\ISIC_0027517.jpg
# images_data\ISIC_0027525.jpg
# images_data\ISIC_0027526.jpg
# images_data\ISIC_0027527.jpg
# images_data\ISIC_0027531.jpg
# images_data\ISIC_0027533.jpg
# images_data\ISIC_0027541.jpg
# images_data\ISIC_0027544.jpg
# images_data\ISIC_0027545.jpg
# images_data\ISIC_0027546.jpg
# images_data\ISIC_0027552.jpg
# images_data\ISIC_0027554.jpg
# images_data\ISIC_0027557.jpg
# images_data\ISIC_0027559.jpg
# images_data\ISIC_0027560.jpg
# images_data\ISIC_0027561.jpg
# images_data\ISIC_0027564.jpg
# images_data\ISIC_0027566.jpg
# images_data\ISIC_0027572.jpg
# images_data\ISIC_0027573.jpg
# images_data\ISIC_0027575.jpg
# images_data\ISIC_0027576.jpg
# images_data\ISIC_0027579.jpg
# images_data\ISIC_0027584.jpg
# images_data\ISIC_0027585.jpg
# images_data\ISIC_0027590.jpg
# images_data\ISIC_0027591.jpg
# images_data\ISIC_0027595.jpg
# images_data\ISIC_0027597.jpg
# images_data\ISIC_0027600.jpg
# images_data\ISIC_0027601.jpg
# images_data\ISIC_0027604.jpg
# images_data\ISIC_0027605.jpg
# images_data\ISIC_0027606.jpg
# images_data\ISIC_0027608.jpg
# images_data\ISIC_0027609.jpg
# images_data\ISIC_0027610.jpg
# images_data\ISIC_0027612.jpg
# images_data\ISIC_0027616.jpg
# images_data\ISIC_0027620.jpg
# images_data\ISIC_0027621.jpg
# images_data\ISIC_0027622.jpg
# images_data\ISIC_0027629.jpg
# images_data\ISIC_0027631.jpg
# images_data\ISIC_0027634.jpg
# images_data\ISIC_0027646.jpg
# images_data\ISIC_0027649.jpg
# images_data\ISIC_0027651.jpg
# images_data\ISIC_0027652.jpg
# images_data\ISIC_0027657.jpg
# images_data\ISIC_0027659.jpg
# images_data\ISIC_0027661.jpg
# images_data\ISIC_0027663.jpg
# images_data\ISIC_0027669.jpg
# images_data\ISIC_0027673.jpg
# images_data\ISIC_0027675.jpg
# images_data\ISIC_0027677.jpg
# images_data\ISIC_0027680.jpg
# images_data\ISIC_0027681.jpg
# images_data\ISIC_0027691.jpg
# images_data\ISIC_0027693.jpg
# images_data\ISIC_0027702.jpg
# images_data\ISIC_0027703.jpg
# images_data\ISIC_0027704.jpg
# images_data\ISIC_0027706.jpg
# images_data\ISIC_0027710.jpg
# images_data\ISIC_0027713.jpg
# images_data\ISIC_0027717.jpg
# images_data\ISIC_0027721.jpg
# images_data\ISIC_0027722.jpg
# images_data\ISIC_0027725.jpg
# images_data\ISIC_0027732.jpg
# images_data\ISIC_0027735.jpg
# images_data\ISIC_0027736.jpg
# images_data\ISIC_0027737.jpg
# images_data\ISIC_0027739.jpg
# images_data\ISIC_0027742.jpg
# images_data\ISIC_0027744.jpg
# images_data\ISIC_0027747.jpg
# images_data\ISIC_0027752.jpg
# images_data\ISIC_0027754.jpg
# images_data\ISIC_0027758.jpg
# images_data\ISIC_0027759.jpg
# images_data\ISIC_0027760.jpg
# images_data\ISIC_0027763.jpg
# images_data\ISIC_0027764.jpg
# images_data\ISIC_0027765.jpg
# images_data\ISIC_0027769.jpg
# images_data\ISIC_0027770.jpg
# images_data\ISIC_0027771.jpg
# images_data\ISIC_0027774.jpg
# images_data\ISIC_0027776.jpg
# images_data\ISIC_0027780.jpg
# images_data\ISIC_0027781.jpg
# images_data\ISIC_0027784.jpg
# images_data\ISIC_0027786.jpg
# images_data\ISIC_0027788.jpg
# images_data\ISIC_0027793.jpg
# images_data\ISIC_0027796.jpg
# images_data\ISIC_0027797.jpg
# images_data\ISIC_0027801.jpg
# images_data\ISIC_0027806.jpg
# images_data\ISIC_0027808.jpg
# images_data\ISIC_0027810.jpg
# images_data\ISIC_0027811.jpg
# images_data\ISIC_0027814.jpg
# images_data\ISIC_0027815.jpg
# images_data\ISIC_0027816.jpg
# images_data\ISIC_0027819.jpg
# images_data\ISIC_0027820.jpg
# images_data\ISIC_0027822.jpg
# images_data\ISIC_0027825.jpg
# images_data\ISIC_0027826.jpg
# images_data\ISIC_0027828.jpg
# images_data\ISIC_0027831.jpg
# images_data\ISIC_0027832.jpg
# images_data\ISIC_0027834.jpg
# images_data\ISIC_0027836.jpg
# images_data\ISIC_0027838.jpg
# images_data\ISIC_0027843.jpg
# images_data\ISIC_0027846.jpg
# images_data\ISIC_0027850.jpg
# images_data\ISIC_0027851.jpg
# images_data\ISIC_0027854.jpg
# images_data\ISIC_0027858.jpg
# images_data\ISIC_0027859.jpg
# images_data\ISIC_0027863.jpg
# images_data\ISIC_0027865.jpg
# images_data\ISIC_0027868.jpg
# images_data\ISIC_0027869.jpg
# images_data\ISIC_0027871.jpg
# images_data\ISIC_0027872.jpg
# images_data\ISIC_0027875.jpg
# images_data\ISIC_0027881.jpg
# images_data\ISIC_0027886.jpg
# images_data\ISIC_0027892.jpg
# images_data\ISIC_0027893.jpg
# images_data\ISIC_0027900.jpg
# images_data\ISIC_0027904.jpg
# images_data\ISIC_0027905.jpg
# images_data\ISIC_0027910.jpg
# images_data\ISIC_0027912.jpg
# images_data\ISIC_0027915.jpg
# images_data\ISIC_0027916.jpg
# images_data\ISIC_0027919.jpg
# images_data\ISIC_0027920.jpg
# images_data\ISIC_0027932.jpg
# images_data\ISIC_0027935.jpg
# images_data\ISIC_0027938.jpg
# images_data\ISIC_0027939.jpg
# images_data\ISIC_0027944.jpg
# images_data\ISIC_0027953.jpg
# images_data\ISIC_0027954.jpg
# images_data\ISIC_0027956.jpg
# images_data\ISIC_0027957.jpg
# images_data\ISIC_0027960.jpg
# images_data\ISIC_0027964.jpg
# images_data\ISIC_0027966.jpg
# images_data\ISIC_0027967.jpg
# images_data\ISIC_0027969.jpg
# images_data\ISIC_0027971.jpg
# images_data\ISIC_0027973.jpg
# images_data\ISIC_0027974.jpg
# images_data\ISIC_0027976.jpg
# images_data\ISIC_0027982.jpg
# images_data\ISIC_0027989.jpg
# images_data\ISIC_0027990.jpg
# images_data\ISIC_0027991.jpg
# images_data\ISIC_0027996.jpg
# images_data\ISIC_0027998.jpg
# images_data\ISIC_0028003.jpg
# images_data\ISIC_0028007.jpg
# images_data\ISIC_0028017.jpg
# images_data\ISIC_0028020.jpg
# images_data\ISIC_0028022.jpg
# images_data\ISIC_0028025.jpg
# images_data\ISIC_0028026.jpg
# images_data\ISIC_0028029.jpg
# images_data\ISIC_0028033.jpg
# images_data\ISIC_0028034.jpg
# images_data\ISIC_0028035.jpg
# images_data\ISIC_0028041.jpg
# images_data\ISIC_0028043.jpg
# images_data\ISIC_0028044.jpg
# images_data\ISIC_0028048.jpg
# images_data\ISIC_0028050.jpg
# images_data\ISIC_0028051.jpg
# images_data\ISIC_0028052.jpg
# images_data\ISIC_0028054.jpg
# images_data\ISIC_0028056.jpg
# images_data\ISIC_0028058.jpg
# images_data\ISIC_0028059.jpg
# images_data\ISIC_0028062.jpg
# images_data\ISIC_0028065.jpg
# images_data\ISIC_0028069.jpg
# images_data\ISIC_0028075.jpg
# images_data\ISIC_0028077.jpg
# images_data\ISIC_0028079.jpg
# images_data\ISIC_0028080.jpg
# images_data\ISIC_0028082.jpg
# images_data\ISIC_0028084.jpg
# images_data\ISIC_0028085.jpg
# images_data\ISIC_0028086.jpg
# images_data\ISIC_0028087.jpg
# images_data\ISIC_0028090.jpg
# images_data\ISIC_0028094.jpg
# images_data\ISIC_0028095.jpg
# images_data\ISIC_0028100.jpg
# images_data\ISIC_0028102.jpg
# images_data\ISIC_0028103.jpg
# images_data\ISIC_0028104.jpg
# images_data\ISIC_0028105.jpg
# images_data\ISIC_0028106.jpg
# images_data\ISIC_0028107.jpg
# images_data\ISIC_0028108.jpg
# images_data\ISIC_0028109.jpg
# images_data\ISIC_0028111.jpg
# images_data\ISIC_0028113.jpg
# images_data\ISIC_0028114.jpg
# images_data\ISIC_0028120.jpg
# images_data\ISIC_0028121.jpg
# images_data\ISIC_0028122.jpg
# images_data\ISIC_0028123.jpg
# images_data\ISIC_0028124.jpg
# images_data\ISIC_0028126.jpg
# images_data\ISIC_0028127.jpg
# images_data\ISIC_0028136.jpg
# images_data\ISIC_0028137.jpg
# images_data\ISIC_0028142.jpg
# images_data\ISIC_0028147.jpg
# images_data\ISIC_0028148.jpg
# images_data\ISIC_0028155.jpg
# images_data\ISIC_0028156.jpg
# images_data\ISIC_0028160.jpg
# images_data\ISIC_0028164.jpg
# images_data\ISIC_0028165.jpg
# images_data\ISIC_0028168.jpg
# images_data\ISIC_0028173.jpg
# images_data\ISIC_0028175.jpg
# images_data\ISIC_0028177.jpg
# images_data\ISIC_0028180.jpg
# images_data\ISIC_0028184.jpg
# images_data\ISIC_0028185.jpg
# images_data\ISIC_0028196.jpg
# images_data\ISIC_0028197.jpg
# images_data\ISIC_0028198.jpg
# images_data\ISIC_0028200.jpg
# images_data\ISIC_0028201.jpg
# images_data\ISIC_0028209.jpg
# images_data\ISIC_0028211.jpg
# images_data\ISIC_0028215.jpg
# images_data\ISIC_0028218.jpg
# images_data\ISIC_0028219.jpg
# images_data\ISIC_0028220.jpg
# images_data\ISIC_0028223.jpg
# images_data\ISIC_0028225.jpg
# images_data\ISIC_0028227.jpg
# images_data\ISIC_0028228.jpg
# images_data\ISIC_0028229.jpg
# images_data\ISIC_0028233.jpg
# images_data\ISIC_0028236.jpg
# images_data\ISIC_0028237.jpg
# images_data\ISIC_0028238.jpg
# images_data\ISIC_0028239.jpg
# images_data\ISIC_0028242.jpg
# images_data\ISIC_0028254.jpg
# images_data\ISIC_0028258.jpg
# images_data\ISIC_0028260.jpg
# images_data\ISIC_0028264.jpg
# images_data\ISIC_0028266.jpg
# images_data\ISIC_0028270.jpg
# images_data\ISIC_0028282.jpg
# images_data\ISIC_0028283.jpg
# images_data\ISIC_0028285.jpg
# images_data\ISIC_0028288.jpg
# images_data\ISIC_0028289.jpg
# images_data\ISIC_0028291.jpg
# images_data\ISIC_0028294.jpg
# images_data\ISIC_0028298.jpg
# images_data\ISIC_0028299.jpg
# images_data\ISIC_0028302.jpg
# images_data\ISIC_0028303.jpg
# images_data\ISIC_0028306.jpg
# images_data\ISIC_0028308.jpg
# images_data\ISIC_0028309.jpg
# images_data\ISIC_0028316.jpg
# images_data\ISIC_0028317.jpg
# images_data\ISIC_0028319.jpg
# images_data\ISIC_0028323.jpg
# images_data\ISIC_0028325.jpg
# images_data\ISIC_0028326.jpg
# images_data\ISIC_0028329.jpg
# images_data\ISIC_0028331.jpg
# images_data\ISIC_0028336.jpg
# images_data\ISIC_0028337.jpg
# images_data\ISIC_0028339.jpg
# images_data\ISIC_0028343.jpg
# images_data\ISIC_0028347.jpg
# images_data\ISIC_0028349.jpg
# images_data\ISIC_0028350.jpg
# images_data\ISIC_0028352.jpg
# images_data\ISIC_0028353.jpg
# images_data\ISIC_0028354.jpg
# images_data\ISIC_0028356.jpg
# images_data\ISIC_0028359.jpg
# images_data\ISIC_0028361.jpg
# images_data\ISIC_0028365.jpg
# images_data\ISIC_0028375.jpg
# images_data\ISIC_0028376.jpg
# images_data\ISIC_0028377.jpg
# images_data\ISIC_0028386.jpg
# images_data\ISIC_0028388.jpg
# images_data\ISIC_0028389.jpg
# images_data\ISIC_0028395.jpg
# images_data\ISIC_0028403.jpg
# images_data\ISIC_0028404.jpg
# images_data\ISIC_0028410.jpg
# images_data\ISIC_0028411.jpg
# images_data\ISIC_0028412.jpg
# images_data\ISIC_0028414.jpg
# images_data\ISIC_0028415.jpg
# images_data\ISIC_0028418.jpg
# images_data\ISIC_0028419.jpg
# images_data\ISIC_0028424.jpg
# images_data\ISIC_0028426.jpg
# images_data\ISIC_0028428.jpg
# images_data\ISIC_0028442.jpg
# images_data\ISIC_0028443.jpg
# images_data\ISIC_0028445.jpg
# images_data\ISIC_0028446.jpg
# images_data\ISIC_0028448.jpg
# images_data\ISIC_0028449.jpg
# images_data\ISIC_0028451.jpg
# images_data\ISIC_0028455.jpg
# images_data\ISIC_0028457.jpg
# images_data\ISIC_0028460.jpg
# images_data\ISIC_0028462.jpg
# images_data\ISIC_0028463.jpg
# images_data\ISIC_0028465.jpg
# images_data\ISIC_0028466.jpg
# images_data\ISIC_0028467.jpg
# images_data\ISIC_0028473.jpg
# images_data\ISIC_0028479.jpg
# images_data\ISIC_0028480.jpg
# images_data\ISIC_0028481.jpg
# images_data\ISIC_0028482.jpg
# images_data\ISIC_0028486.jpg
# images_data\ISIC_0028489.jpg
# images_data\ISIC_0028490.jpg
# images_data\ISIC_0028493.jpg
# images_data\ISIC_0028495.jpg
# images_data\ISIC_0028496.jpg
# images_data\ISIC_0028497.jpg
# images_data\ISIC_0028502.jpg
# images_data\ISIC_0028503.jpg
# images_data\ISIC_0028505.jpg
# images_data\ISIC_0028508.jpg
# images_data\ISIC_0028511.jpg
# images_data\ISIC_0028512.jpg
# images_data\ISIC_0028515.jpg
# images_data\ISIC_0028519.jpg
# images_data\ISIC_0028520.jpg
# images_data\ISIC_0028523.jpg
# images_data\ISIC_0028525.jpg
# images_data\ISIC_0028537.jpg
# images_data\ISIC_0028539.jpg
# images_data\ISIC_0028542.jpg
# images_data\ISIC_0028543.jpg
# images_data\ISIC_0028546.jpg
# images_data\ISIC_0028548.jpg
# images_data\ISIC_0028550.jpg
# images_data\ISIC_0028554.jpg
# images_data\ISIC_0028555.jpg
# images_data\ISIC_0028556.jpg
# images_data\ISIC_0028560.jpg
# images_data\ISIC_0028565.jpg
# images_data\ISIC_0028567.jpg
# images_data\ISIC_0028568.jpg
# images_data\ISIC_0028570.jpg
# images_data\ISIC_0028572.jpg
# images_data\ISIC_0028577.jpg
# images_data\ISIC_0028579.jpg
# images_data\ISIC_0028582.jpg
# images_data\ISIC_0028583.jpg
# images_data\ISIC_0028584.jpg
# images_data\ISIC_0028587.jpg
# images_data\ISIC_0028593.jpg
# images_data\ISIC_0028594.jpg
# images_data\ISIC_0028597.jpg
# images_data\ISIC_0028607.jpg
# images_data\ISIC_0028609.jpg
# images_data\ISIC_0028611.jpg
# images_data\ISIC_0028613.jpg
# images_data\ISIC_0028615.jpg
# images_data\ISIC_0028622.jpg
# images_data\ISIC_0028623.jpg
# images_data\ISIC_0028628.jpg
# images_data\ISIC_0028639.jpg
# images_data\ISIC_0028640.jpg
# images_data\ISIC_0028642.jpg
# images_data\ISIC_0028646.jpg
# images_data\ISIC_0028650.jpg
# images_data\ISIC_0028652.jpg
# images_data\ISIC_0028653.jpg
# images_data\ISIC_0028655.jpg
# images_data\ISIC_0028656.jpg
# images_data\ISIC_0028660.jpg
# images_data\ISIC_0028662.jpg
# images_data\ISIC_0028666.jpg
# images_data\ISIC_0028668.jpg
# images_data\ISIC_0028670.jpg
# images_data\ISIC_0028671.jpg
# images_data\ISIC_0028677.jpg
# images_data\ISIC_0028681.jpg
# images_data\ISIC_0028682.jpg
# images_data\ISIC_0028685.jpg
# images_data\ISIC_0028687.jpg
# images_data\ISIC_0028688.jpg
# images_data\ISIC_0028690.jpg
# images_data\ISIC_0028693.jpg
# images_data\ISIC_0028694.jpg
# images_data\ISIC_0028696.jpg
# images_data\ISIC_0028699.jpg
# images_data\ISIC_0028701.jpg
# images_data\ISIC_0028702.jpg
# images_data\ISIC_0028705.jpg
# images_data\ISIC_0028707.jpg
# images_data\ISIC_0028709.jpg
# images_data\ISIC_0028710.jpg
# images_data\ISIC_0028711.jpg
# images_data\ISIC_0028712.jpg
# images_data\ISIC_0028718.jpg
# images_data\ISIC_0028719.jpg
# images_data\ISIC_0028721.jpg
# images_data\ISIC_0028727.jpg
# images_data\ISIC_0028728.jpg
# images_data\ISIC_0028739.jpg
# images_data\ISIC_0028746.jpg
# images_data\ISIC_0028747.jpg
# images_data\ISIC_0028749.jpg
# images_data\ISIC_0028750.jpg
# images_data\ISIC_0028760.jpg
# images_data\ISIC_0028764.jpg
# images_data\ISIC_0028765.jpg
# images_data\ISIC_0028768.jpg
# images_data\ISIC_0028770.jpg
# images_data\ISIC_0028773.jpg
# ...
# images_data\ISIC_0032879.jpg
# images_data\ISIC_0032883.jpg
# images_data\ISIC_0032887.jpg
# images_data\ISIC_0032888.jpg
# images_data\ISIC_0032892.jpg
# images_data\ISIC_0032894.jpg
# images_data\ISIC_0032898.jpg
# images_data\ISIC_0032903.jpg
# images_data\ISIC_0032906.jpg
# images_data\ISIC_0032913.jpg
# images_data\ISIC_0032915.jpg
# images_data\ISIC_0032917.jpg
# images_data\ISIC_0032918.jpg
# images_data\ISIC_0032921.jpg
# images_data\ISIC_0032922.jpg
# images_data\ISIC_0032925.jpg
# images_data\ISIC_0032927.jpg
# images_data\ISIC_0032929.jpg
# images_data\ISIC_0032936.jpg
# images_data\ISIC_0032938.jpg
# images_data\ISIC_0032940.jpg
# images_data\ISIC_0032949.jpg
# images_data\ISIC_0032955.jpg
# images_data\ISIC_0032958.jpg
# images_data\ISIC_0032959.jpg
# images_data\ISIC_0032960.jpg
# images_data\ISIC_0032963.jpg
# images_data\ISIC_0032965.jpg
# images_data\ISIC_0032967.jpg
# images_data\ISIC_0032968.jpg
# images_data\ISIC_0032970.jpg
# images_data\ISIC_0032972.jpg
# images_data\ISIC_0032975.jpg
# images_data\ISIC_0032976.jpg
# images_data\ISIC_0032978.jpg
# images_data\ISIC_0032981.jpg
# images_data\ISIC_0032982.jpg
# images_data\ISIC_0032983.jpg
# images_data\ISIC_0032984.jpg
# images_data\ISIC_0032985.jpg
# images_data\ISIC_0032987.jpg
# images_data\ISIC_0032988.jpg
# images_data\ISIC_0032991.jpg
# images_data\ISIC_0032993.jpg
# images_data\ISIC_0032997.jpg
# images_data\ISIC_0033001.jpg
# images_data\ISIC_0033004.jpg
# images_data\ISIC_0033012.jpg
# images_data\ISIC_0033017.jpg
# images_data\ISIC_0033019.jpg
# images_data\ISIC_0033020.jpg
# images_data\ISIC_0033022.jpg
# images_data\ISIC_0033023.jpg
# images_data\ISIC_0033024.jpg
# images_data\ISIC_0033027.jpg
# images_data\ISIC_0033029.jpg
# images_data\ISIC_0033034.jpg
# images_data\ISIC_0033037.jpg
# images_data\ISIC_0033038.jpg
# images_data\ISIC_0033041.jpg
# images_data\ISIC_0033042.jpg
# images_data\ISIC_0033047.jpg
# images_data\ISIC_0033050.jpg
# images_data\ISIC_0033051.jpg
# images_data\ISIC_0033054.jpg
# images_data\ISIC_0033055.jpg
# images_data\ISIC_0033056.jpg
# images_data\ISIC_0033060.jpg
# images_data\ISIC_0033061.jpg
# images_data\ISIC_0033063.jpg
# images_data\ISIC_0033068.jpg
# images_data\ISIC_0033073.jpg
# images_data\ISIC_0033074.jpg
# images_data\ISIC_0033079.jpg
# images_data\ISIC_0033081.jpg
# images_data\ISIC_0033088.jpg
# images_data\ISIC_0033089.jpg
# images_data\ISIC_0033099.jpg
# images_data\ISIC_0033103.jpg
# images_data\ISIC_0033114.jpg
# images_data\ISIC_0033117.jpg
# images_data\ISIC_0033120.jpg
# images_data\ISIC_0033122.jpg
# images_data\ISIC_0033124.jpg
# images_data\ISIC_0033125.jpg
# images_data\ISIC_0033127.jpg
# images_data\ISIC_0033129.jpg
# images_data\ISIC_0033130.jpg
# images_data\ISIC_0033141.jpg
# images_data\ISIC_0033146.jpg
# images_data\ISIC_0033152.jpg
# images_data\ISIC_0033154.jpg
# images_data\ISIC_0033156.jpg
# images_data\ISIC_0033166.jpg
# images_data\ISIC_0033169.jpg
# images_data\ISIC_0033171.jpg
# images_data\ISIC_0033174.jpg
# images_data\ISIC_0033175.jpg
# images_data\ISIC_0033178.jpg
# images_data\ISIC_0033180.jpg
# images_data\ISIC_0033183.jpg
# images_data\ISIC_0033184.jpg
# images_data\ISIC_0033185.jpg
# images_data\ISIC_0033186.jpg
# images_data\ISIC_0033192.jpg
# images_data\ISIC_0033193.jpg
# images_data\ISIC_0033195.jpg
# images_data\ISIC_0033196.jpg
# images_data\ISIC_0033198.jpg
# images_data\ISIC_0033199.jpg
# images_data\ISIC_0033200.jpg
# images_data\ISIC_0033201.jpg
# images_data\ISIC_0033203.jpg
# images_data\ISIC_0033204.jpg
# images_data\ISIC_0033205.jpg
# images_data\ISIC_0033206.jpg
# images_data\ISIC_0033209.jpg
# images_data\ISIC_0033212.jpg
# images_data\ISIC_0033216.jpg
# images_data\ISIC_0033217.jpg
# images_data\ISIC_0033218.jpg
# images_data\ISIC_0033226.jpg
# images_data\ISIC_0033232.jpg
# images_data\ISIC_0033235.jpg
# images_data\ISIC_0033238.jpg
# images_data\ISIC_0033239.jpg
# images_data\ISIC_0033240.jpg
# images_data\ISIC_0033241.jpg
# images_data\ISIC_0033245.jpg
# images_data\ISIC_0033246.jpg
# images_data\ISIC_0033248.jpg
# images_data\ISIC_0033252.jpg
# images_data\ISIC_0033257.jpg
# images_data\ISIC_0033258.jpg
# images_data\ISIC_0033260.jpg
# images_data\ISIC_0033261.jpg
# images_data\ISIC_0033262.jpg
# images_data\ISIC_0033264.jpg
# images_data\ISIC_0033267.jpg
# images_data\ISIC_0033268.jpg
# images_data\ISIC_0033269.jpg
# images_data\ISIC_0033270.jpg
# images_data\ISIC_0033271.jpg
# images_data\ISIC_0033272.jpg
# images_data\ISIC_0033274.jpg
# images_data\ISIC_0033275.jpg
# images_data\ISIC_0033278.jpg
# images_data\ISIC_0033279.jpg
# images_data\ISIC_0033280.jpg
# images_data\ISIC_0033284.jpg
# images_data\ISIC_0033286.jpg
# images_data\ISIC_0033287.jpg
# images_data\ISIC_0033299.jpg
# images_data\ISIC_0033300.jpg
# images_data\ISIC_0033301.jpg
# images_data\ISIC_0033302.jpg
# images_data\ISIC_0033304.jpg
# images_data\ISIC_0033305.jpg
# images_data\ISIC_0033306.jpg
# images_data\ISIC_0033307.jpg
# images_data\ISIC_0033310.jpg
# images_data\ISIC_0033312.jpg
# images_data\ISIC_0033317.jpg
# images_data\ISIC_0033320.jpg
# images_data\ISIC_0033321.jpg
# images_data\ISIC_0033322.jpg
# images_data\ISIC_0033323.jpg
# images_data\ISIC_0033324.jpg
# images_data\ISIC_0033325.jpg
# images_data\ISIC_0033333.jpg
# images_data\ISIC_0033336.jpg
# images_data\ISIC_0033337.jpg
# images_data\ISIC_0033344.jpg
# images_data\ISIC_0033354.jpg
# images_data\ISIC_0033361.jpg
# images_data\ISIC_0033362.jpg
# images_data\ISIC_0033366.jpg
# images_data\ISIC_0033368.jpg
# images_data\ISIC_0033369.jpg
# images_data\ISIC_0033372.jpg
# images_data\ISIC_0033377.jpg
# images_data\ISIC_0033378.jpg
# images_data\ISIC_0033379.jpg
# images_data\ISIC_0033387.jpg
# images_data\ISIC_0033391.jpg
# images_data\ISIC_0033392.jpg
# images_data\ISIC_0033393.jpg
# images_data\ISIC_0033394.jpg
# images_data\ISIC_0033397.jpg
# images_data\ISIC_0033399.jpg
# images_data\ISIC_0033400.jpg
# images_data\ISIC_0033401.jpg
# images_data\ISIC_0033405.jpg
# images_data\ISIC_0033410.jpg
# images_data\ISIC_0033414.jpg
# images_data\ISIC_0033415.jpg
# images_data\ISIC_0033416.jpg
# images_data\ISIC_0033424.jpg
# images_data\ISIC_0033426.jpg
# images_data\ISIC_0033428.jpg
# images_data\ISIC_0033429.jpg
# images_data\ISIC_0033431.jpg
# images_data\ISIC_0033432.jpg
# images_data\ISIC_0033437.jpg
# images_data\ISIC_0033438.jpg
# images_data\ISIC_0033440.jpg
# images_data\ISIC_0033444.jpg
# images_data\ISIC_0033446.jpg
# images_data\ISIC_0033449.jpg
# images_data\ISIC_0033452.jpg
# images_data\ISIC_0033453.jpg
# images_data\ISIC_0033454.jpg
# images_data\ISIC_0033460.jpg
# images_data\ISIC_0033465.jpg
# images_data\ISIC_0033466.jpg
# images_data\ISIC_0033468.jpg
# images_data\ISIC_0033469.jpg
# images_data\ISIC_0033470.jpg
# images_data\ISIC_0033473.jpg
# images_data\ISIC_0033476.jpg
# images_data\ISIC_0033477.jpg
# images_data\ISIC_0033479.jpg
# images_data\ISIC_0033480.jpg
# images_data\ISIC_0033482.jpg
# images_data\ISIC_0033483.jpg
# images_data\ISIC_0033485.jpg
# images_data\ISIC_0033486.jpg
# images_data\ISIC_0033487.jpg
# images_data\ISIC_0033488.jpg
# images_data\ISIC_0033490.jpg
# images_data\ISIC_0033491.jpg
# images_data\ISIC_0033496.jpg
# images_data\ISIC_0033498.jpg
# images_data\ISIC_0033499.jpg
# images_data\ISIC_0033500.jpg
# images_data\ISIC_0033504.jpg
# images_data\ISIC_0033505.jpg
# images_data\ISIC_0033507.jpg
# images_data\ISIC_0033509.jpg
# images_data\ISIC_0033518.jpg
# images_data\ISIC_0033520.jpg
# images_data\ISIC_0033522.jpg
# images_data\ISIC_0033523.jpg
# images_data\ISIC_0033524.jpg
# images_data\ISIC_0033526.jpg
# images_data\ISIC_0033528.jpg
# images_data\ISIC_0033529.jpg
# images_data\ISIC_0033531.jpg
# images_data\ISIC_0033533.jpg
# images_data\ISIC_0033534.jpg
# images_data\ISIC_0033538.jpg
# images_data\ISIC_0033539.jpg
# images_data\ISIC_0033545.jpg
# images_data\ISIC_0033546.jpg
# images_data\ISIC_0033551.jpg
# images_data\ISIC_0033553.jpg
# images_data\ISIC_0033559.jpg
# images_data\ISIC_0033560.jpg
# images_data\ISIC_0033562.jpg
# images_data\ISIC_0033568.jpg
# images_data\ISIC_0033569.jpg
# images_data\ISIC_0033570.jpg
# images_data\ISIC_0033571.jpg
# images_data\ISIC_0033573.jpg
# images_data\ISIC_0033575.jpg
# images_data\ISIC_0033576.jpg
# images_data\ISIC_0033578.jpg
# images_data\ISIC_0033579.jpg
# images_data\ISIC_0033581.jpg
# images_data\ISIC_0033582.jpg
# images_data\ISIC_0033583.jpg
# images_data\ISIC_0033586.jpg
# images_data\ISIC_0033587.jpg
# images_data\ISIC_0033592.jpg
# images_data\ISIC_0033593.jpg
# images_data\ISIC_0033594.jpg
# images_data\ISIC_0033595.jpg
# images_data\ISIC_0033601.jpg
# images_data\ISIC_0033603.jpg
# images_data\ISIC_0033606.jpg
# images_data\ISIC_0033607.jpg
# images_data\ISIC_0033609.jpg
# images_data\ISIC_0033611.jpg
# images_data\ISIC_0033612.jpg
# images_data\ISIC_0033613.jpg
# images_data\ISIC_0033616.jpg
# images_data\ISIC_0033619.jpg
# images_data\ISIC_0033620.jpg
# images_data\ISIC_0033624.jpg
# images_data\ISIC_0033629.jpg
# images_data\ISIC_0033630.jpg
# images_data\ISIC_0033631.jpg
# images_data\ISIC_0033635.jpg
# images_data\ISIC_0033636.jpg
# images_data\ISIC_0033638.jpg
# images_data\ISIC_0033642.jpg
# images_data\ISIC_0033643.jpg
# images_data\ISIC_0033644.jpg
# images_data\ISIC_0033646.jpg
# images_data\ISIC_0033651.jpg
# images_data\ISIC_0033653.jpg
# images_data\ISIC_0033654.jpg
# images_data\ISIC_0033655.jpg
# images_data\ISIC_0033659.jpg
# images_data\ISIC_0033660.jpg
# images_data\ISIC_0033662.jpg
# images_data\ISIC_0033663.jpg
# images_data\ISIC_0033666.jpg
# images_data\ISIC_0033668.jpg
# images_data\ISIC_0033670.jpg
# images_data\ISIC_0033676.jpg
# images_data\ISIC_0033677.jpg
# images_data\ISIC_0033678.jpg
# images_data\ISIC_0033679.jpg
# images_data\ISIC_0033685.jpg
# images_data\ISIC_0033687.jpg
# images_data\ISIC_0033691.jpg
# images_data\ISIC_0033693.jpg
# images_data\ISIC_0033696.jpg
# images_data\ISIC_0033700.jpg
# images_data\ISIC_0033701.jpg
# images_data\ISIC_0033704.jpg
# images_data\ISIC_0033708.jpg
# images_data\ISIC_0033709.jpg
# images_data\ISIC_0033710.jpg
# images_data\ISIC_0033713.jpg
# images_data\ISIC_0033716.jpg
# images_data\ISIC_0033717.jpg
# images_data\ISIC_0033720.jpg
# images_data\ISIC_0033722.jpg
# images_data\ISIC_0033725.jpg
# images_data\ISIC_0033728.jpg
# images_data\ISIC_0033730.jpg
# images_data\ISIC_0033732.jpg
# images_data\ISIC_0033736.jpg
# images_data\ISIC_0033744.jpg
# images_data\ISIC_0033747.jpg
# images_data\ISIC_0033750.jpg
# images_data\ISIC_0033752.jpg
# images_data\ISIC_0033754.jpg
# images_data\ISIC_0033758.jpg
# images_data\ISIC_0033761.jpg
# images_data\ISIC_0033770.jpg
# images_data\ISIC_0033773.jpg
# images_data\ISIC_0033776.jpg
# images_data\ISIC_0033778.jpg
# images_data\ISIC_0033779.jpg
# images_data\ISIC_0033783.jpg
# images_data\ISIC_0033784.jpg
# images_data\ISIC_0033785.jpg
# images_data\ISIC_0033791.jpg
# images_data\ISIC_0033801.jpg
# images_data\ISIC_0033802.jpg
# images_data\ISIC_0033804.jpg
# images_data\ISIC_0033805.jpg
# images_data\ISIC_0033806.jpg
# images_data\ISIC_0033807.jpg
# images_data\ISIC_0033812.jpg
# images_data\ISIC_0033813.jpg
# images_data\ISIC_0033814.jpg
# images_data\ISIC_0033819.jpg
# images_data\ISIC_0033820.jpg
# images_data\ISIC_0033828.jpg
# images_data\ISIC_0033829.jpg
# images_data\ISIC_0033831.jpg
# images_data\ISIC_0033834.jpg
# images_data\ISIC_0033843.jpg
# images_data\ISIC_0033848.jpg
# images_data\ISIC_0033853.jpg
# images_data\ISIC_0033854.jpg
# images_data\ISIC_0033855.jpg
# images_data\ISIC_0033856.jpg
# images_data\ISIC_0033863.jpg
# images_data\ISIC_0033865.jpg
# images_data\ISIC_0033868.jpg
# images_data\ISIC_0033871.jpg
# images_data\ISIC_0033872.jpg
# images_data\ISIC_0033874.jpg
# images_data\ISIC_0033878.jpg
# images_data\ISIC_0033881.jpg
# images_data\ISIC_0033883.jpg
# images_data\ISIC_0033884.jpg
# images_data\ISIC_0033885.jpg
# images_data\ISIC_0033886.jpg
# images_data\ISIC_0033893.jpg
# images_data\ISIC_0033899.jpg
# images_data\ISIC_0033900.jpg
# images_data\ISIC_0033901.jpg
# images_data\ISIC_0033902.jpg
# images_data\ISIC_0033905.jpg
# images_data\ISIC_0033908.jpg
# images_data\ISIC_0033910.jpg
# images_data\ISIC_0033911.jpg
# images_data\ISIC_0033913.jpg
# images_data\ISIC_0033924.jpg
# images_data\ISIC_0033925.jpg
# images_data\ISIC_0033931.jpg
# images_data\ISIC_0033938.jpg
# images_data\ISIC_0033942.jpg
# images_data\ISIC_0033945.jpg
# images_data\ISIC_0033946.jpg
# images_data\ISIC_0033947.jpg
# images_data\ISIC_0033949.jpg
# images_data\ISIC_0033952.jpg
# images_data\ISIC_0033953.jpg
# images_data\ISIC_0033956.jpg
# images_data\ISIC_0033957.jpg
# images_data\ISIC_0033962.jpg
# images_data\ISIC_0033967.jpg
# images_data\ISIC_0033968.jpg
# images_data\ISIC_0033973.jpg
# images_data\ISIC_0033975.jpg
# images_data\ISIC_0033977.jpg
# images_data\ISIC_0033979.jpg
# images_data\ISIC_0033980.jpg
# images_data\ISIC_0033981.jpg
# images_data\ISIC_0033985.jpg
# images_data\ISIC_0033986.jpg
# images_data\ISIC_0033987.jpg
# images_data\ISIC_0033995.jpg
# images_data\ISIC_0033999.jpg
# images_data\ISIC_0034000.jpg
# images_data\ISIC_0034002.jpg
# images_data\ISIC_0034003.jpg
# images_data\ISIC_0034005.jpg
# images_data\ISIC_0034006.jpg
# images_data\ISIC_0034007.jpg
# images_data\ISIC_0034011.jpg
# images_data\ISIC_0034012.jpg
# images_data\ISIC_0034015.jpg
# images_data\ISIC_0034022.jpg
# images_data\ISIC_0034024.jpg
# images_data\ISIC_0034026.jpg
# images_data\ISIC_0034028.jpg
# images_data\ISIC_0034031.jpg
# images_data\ISIC_0034034.jpg
# images_data\ISIC_0034036.jpg
# images_data\ISIC_0034037.jpg
# images_data\ISIC_0034040.jpg
# images_data\ISIC_0034046.jpg
# images_data\ISIC_0034047.jpg
# images_data\ISIC_0034048.jpg
# images_data\ISIC_0034049.jpg
# images_data\ISIC_0034050.jpg
# images_data\ISIC_0034051.jpg
# images_data\ISIC_0034052.jpg
# images_data\ISIC_0034057.jpg
# images_data\ISIC_0034058.jpg
# images_data\ISIC_0034059.jpg
# images_data\ISIC_0034061.jpg
# images_data\ISIC_0034062.jpg
# images_data\ISIC_0034064.jpg
# images_data\ISIC_0034065.jpg
# images_data\ISIC_0034066.jpg
# images_data\ISIC_0034068.jpg
# images_data\ISIC_0034070.jpg
# images_data\ISIC_0034071.jpg
# images_data\ISIC_0034074.jpg
# images_data\ISIC_0034076.jpg
# images_data\ISIC_0034085.jpg
# images_data\ISIC_0034087.jpg
# images_data\ISIC_0034089.jpg
# images_data\ISIC_0034092.jpg
# images_data\ISIC_0034093.jpg
# images_data\ISIC_0034094.jpg
# images_data\ISIC_0034095.jpg
# images_data\ISIC_0034100.jpg
# images_data\ISIC_0034101.jpg
# images_data\ISIC_0034103.jpg
# images_data\ISIC_0034104.jpg
# images_data\ISIC_0034106.jpg
# images_data\ISIC_0034107.jpg
# images_data\ISIC_0034113.jpg
# images_data\ISIC_0034115.jpg
# images_data\ISIC_0034117.jpg
# images_data\ISIC_0034118.jpg
# images_data\ISIC_0034119.jpg
# images_data\ISIC_0034120.jpg
# images_data\ISIC_0034123.jpg
# images_data\ISIC_0034125.jpg
# images_data\ISIC_0034126.jpg
# images_data\ISIC_0034132.jpg
# images_data\ISIC_0034134.jpg
# images_data\ISIC_0034140.jpg
# images_data\ISIC_0034141.jpg
# images_data\ISIC_0034142.jpg
# images_data\ISIC_0034143.jpg
# images_data\ISIC_0034145.jpg
# images_data\ISIC_0034150.jpg
# images_data\ISIC_0034151.jpg
# images_data\ISIC_0034155.jpg
# images_data\ISIC_0034159.jpg
# images_data\ISIC_0034160.jpg
# images_data\ISIC_0034161.jpg
# images_data\ISIC_0034162.jpg
# images_data\ISIC_0034165.jpg
# images_data\ISIC_0034167.jpg
# images_data\ISIC_0034168.jpg
# images_data\ISIC_0034170.jpg
# images_data\ISIC_0034172.jpg
# images_data\ISIC_0034173.jpg
# images_data\ISIC_0034175.jpg
# images_data\ISIC_0034180.jpg
# images_data\ISIC_0034183.jpg
# images_data\ISIC_0034186.jpg
# images_data\ISIC_0034188.jpg
# images_data\ISIC_0034189.jpg
# images_data\ISIC_0034197.jpg
# images_data\ISIC_0034201.jpg
# images_data\ISIC_0034202.jpg
# images_data\ISIC_0034205.jpg
# images_data\ISIC_0034208.jpg
# images_data\ISIC_0034211.jpg
# images_data\ISIC_0034216.jpg
# images_data\ISIC_0034218.jpg
# images_data\ISIC_0034221.jpg
# images_data\ISIC_0034222.jpg
# images_data\ISIC_0034223.jpg
# images_data\ISIC_0034233.jpg
# images_data\ISIC_0034235.jpg
# images_data\ISIC_0034236.jpg
# images_data\ISIC_0034239.jpg
# images_data\ISIC_0034242.jpg
# images_data\ISIC_0034243.jpg
# images_data\ISIC_0034246.jpg
# images_data\ISIC_0034252.jpg
# images_data\ISIC_0034253.jpg
# images_data\ISIC_0034255.jpg
# images_data\ISIC_0034256.jpg
# images_data\ISIC_0034259.jpg
# images_data\ISIC_0034262.jpg
# images_data\ISIC_0034263.jpg
# images_data\ISIC_0034269.jpg
# images_data\ISIC_0034275.jpg
# images_data\ISIC_0034276.jpg
# images_data\ISIC_0034280.jpg
# images_data\ISIC_0034283.jpg
# images_data\ISIC_0034284.jpg
# images_data\ISIC_0034287.jpg
# images_data\ISIC_0034289.jpg
# images_data\ISIC_0034291.jpg
# images_data\ISIC_0034294.jpg
# images_data\ISIC_0034296.jpg
# images_data\ISIC_0034299.jpg
# images_data\ISIC_0034303.jpg
# images_data\ISIC_0034306.jpg
# images_data\ISIC_0034313.jpg
# images_data\ISIC_0034315.jpg
# images_data\ISIC_0034316.jpg
# images_data\ISIC_0034317.jpg
# images_data\ISIC_0034318.jpg

# %%
x_train, x_test, y_train, y_test = train_test_split(images,labels,test_size=0.2,random_state=42, stratify=labels)

# %%
Xtrain = np.array(x_train)
Xtest = np.array(x_test)
Xtrain = Xtrain/255
Xtest = Xtest/255
ytrain = np.array(y_train)
ytest = np.array(y_test)

# %%
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'species'.
ytest= label_encoder.fit_transform(ytest)

# %%
ytrain= label_encoder.fit_transform(ytrain)

# %% [markdown]
# # Support vector machine

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB 
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from mlxtend.classifier import StackingClassifier
from sklearn.model_selection import GridSearchCV

# %%
model = SVC(decision_function_shape='ovo',class_weight='balanced')
model.fit(Xtrain,ytrain)
# Out:
# SVC(class_weight='balanced', decision_function_shape='ovo')

# %%
test_prediction = model.predict(Xtest)

# %%
print(classification_report(ytest, test_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.19      0.31       103
#            1       0.45      0.52      0.48       220
#            2       0.56      0.57      0.56       223
#            3       0.71      0.84      0.77       200
#
#     accuracy                           0.58       746
#    macro avg       0.62      0.53      0.53       746
# weighted avg       0.59      0.58      0.56       746

# %% [markdown]
# ## Hyperparamter tunning of SVM

# %%
grid = {'C': [0.1, 1],
        'gamma': [0.1, 0.01]}

# %%
best_svc = GridSearchCV(estimator=model, param_grid=grid, cv= 3,n_jobs=-1)
best_svc.fit(Xtrain,ytrain)
# Out:
# GridSearchCV(cv=3,
#              estimator=SVC(class_weight='balanced',
#                            decision_function_shape='ovo'),
#              n_jobs=-1, param_grid={'C': [0.1, 1], 'gamma': [0.1, 0.01]})

# %%
best_svc.best_params_
# Out:
# {'C': 1, 'gamma': 0.1}

# %%
svm=SVC(decision_function_shape='ovo',**best_svc.best_params_,class_weight='balanced')
svm.fit(Xtrain,ytrain)
# Out:
# SVC(C=1, class_weight='balanced', decision_function_shape='ovo', gamma=0.1)

# %%
pred=svm.predict(Xtest)
print(classification_report(ytest, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       103
#            1       0.00      0.00      0.00       220
#            2       0.30      1.00      0.46       223
#            3       0.00      0.00      0.00       200
#
#     accuracy                           0.30       746
#    macro avg       0.07      0.25      0.12       746
# weighted avg       0.09      0.30      0.14       746

# %% [markdown]
# # Logistic regression

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(multi_class='multinomial', solver='lbfgs', class_weight='balanced')
model.fit(Xtrain,ytrain)
# Out:
# LogisticRegression(class_weight='balanced', multi_class='multinomial')

# %%
pred=model.predict(Xtest)

# %%
print(classification_report(ytest, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.27      0.50      0.35       103
#            1       0.42      0.21      0.28       220
#            2       0.52      0.24      0.33       223
#            3       0.45      0.76      0.56       200
#
#     accuracy                           0.41       746
#    macro avg       0.41      0.43      0.38       746
# weighted avg       0.44      0.41      0.38       746

# %% [markdown]
# ## Hyperparamter tunning of Logistic regression

# %%
grid={"C":np.logspace(-4,4,7), "penalty":["l1","l2"]}

# %%
best_lr = GridSearchCV(estimator=model, param_grid=grid, cv= 3,n_jobs=-1)
best_lr.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=LogisticRegression(class_weight='balanced',
#                                           multi_class='multinomial'),
#              n_jobs=-1,
#              param_grid={'C': array([1.00000000e-04, 2.15443469e-03, 4.64158883e-02, 1.00000000e+00,
#        2.15443469e+01, 4.64158883e+02, 1.00000000e+04]),
#                          'penalty': ['l1', 'l2']})

# %%
best_lr.best_params_
# Out:
# {'C': 0.002154434690031882, 'penalty': 'l2'}

# %%
lr = LogisticRegression(multi_class='multinomial', solver='lbfgs', class_weight='balanced',**best_lr.best_params_)
lr.fit(Xtrain,ytrain)
# Out:
# LogisticRegression(C=0.002154434690031882, class_weight='balanced',
#                    multi_class='multinomial')

# %%
pred=lr.predict(Xtest)
print(classification_report(ytest, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.27      0.50      0.35       103
#            1       0.41      0.20      0.27       220
#            2       0.51      0.22      0.31       223
#            3       0.44      0.76      0.55       200
#
#     accuracy                           0.40       746
#    macro avg       0.41      0.42      0.37       746
# weighted avg       0.43      0.40      0.37       746

# %% [markdown]
# # Stacking classifier

# %%
clf1 = KNeighborsClassifier(n_neighbors=4)
clf2 = RandomForestClassifier(class_weight='balanced')
clf3 = MultinomialNB()
lr = LogisticRegression(multi_class='multinomial',class_weight='balanced')

# %%
sclf = StackingClassifier(classifiers=[clf1, clf2, clf3], 
                          meta_classifier=lr)

print('3-fold cross validation:\n')

for clf, label in zip([clf1, clf2, clf3, sclf], 
                      ['KNN', 
                       'Random Forest', 
                       'Naive Bayes',
                       'StackingClassifier']):

    scores = model_selection.cross_val_score(clf, x_train, y_train, 
                                              cv=3, scoring='accuracy')
    print("Accuracy: %0.2f (+/- %0.2f) [%s]" 
          % (scores.mean(), scores.std(), label))
# Out:
# 3-fold cross validation:
#
# Accuracy: 0.29 (+/- 0.01) [KNN]
# Accuracy: 0.48 (+/- 0.01) [Random Forest]
# Accuracy: 0.42 (+/- 0.01) [Naive Bayes]
# Accuracy: nan (+/- nan) [StackingClassifier]

# %%
sclf.fit(Xtrain,ytrain)
# Out:
# StackingClassifier(classifiers=[KNeighborsClassifier(n_neighbors=4),
#                                 RandomForestClassifier(class_weight='balanced'),
#                                 MultinomialNB()],
#                    meta_classifier=LogisticRegression(class_weight='balanced',
#                                                       multi_class='multinomial'))

# %%
pred=sclf.predict(Xtest)
print(classification_report(ytest, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       103
#            1       0.42      0.51      0.46       220
#            2       0.48      0.52      0.50       223
#            3       0.65      0.78      0.71       200
#
#     accuracy                           0.51       746
#    macro avg       0.39      0.45      0.42       746
# weighted avg       0.44      0.51      0.48       746

# %% [markdown]
# ## Stacking classifier using grid search

# %%
params = {'kneighborsclassifier__n_neighbors': [1, 5],
          'randomforestclassifier__n_estimators': [10, 50],
          'meta_classifier__C': [0.1, 10.0]}

grid = GridSearchCV(estimator=sclf, 
                    param_grid=params, 
                    cv=5,
                    refit=True)
grid.fit(Xtrain,ytrain)

cv_keys = ('mean_test_score', 'std_test_score', 'params')

for r, _ in enumerate(grid.cv_results_['mean_test_score']):
    print("%0.3f +/- %0.2f %r"
          % (grid.cv_results_[cv_keys[0]][r],
             grid.cv_results_[cv_keys[1]][r] / 2.0,
             grid.cv_results_[cv_keys[2]][r]))
# Out:
# 0.359 +/- 0.01 {'kneighborsclassifier__n_neighbors': 1, 'meta_classifier__C': 0.1, 'randomforestclassifier__n_estimators': 10}
# 0.388 +/- 0.01 {'kneighborsclassifier__n_neighbors': 1, 'meta_classifier__C': 0.1, 'randomforestclassifier__n_estimators': 50}
# 0.317 +/- 0.01 {'kneighborsclassifier__n_neighbors': 1, 'meta_classifier__C': 10.0, 'randomforestclassifier__n_estimators': 10}
# 0.428 +/- 0.01 {'kneighborsclassifier__n_neighbors': 1, 'meta_classifier__C': 10.0, 'randomforestclassifier__n_estimators': 50}
# 0.379 +/- 0.01 {'kneighborsclassifier__n_neighbors': 5, 'meta_classifier__C': 0.1, 'randomforestclassifier__n_estimators': 10}
# 0.461 +/- 0.01 {'kneighborsclassifier__n_neighbors': 5, 'meta_classifier__C': 0.1, 'randomforestclassifier__n_estimators': 50}
# 0.381 +/- 0.01 {'kneighborsclassifier__n_neighbors': 5, 'meta_classifier__C': 10.0, 'randomforestclassifier__n_estimators': 10}
# 0.445 +/- 0.00 {'kneighborsclassifier__n_neighbors': 5, 'meta_classifier__C': 10.0, 'randomforestclassifier__n_estimators': 50}

# %%
print('Best parameters: %s' % grid.best_params_)
print('Accuracy: %.2f' % grid.best_score_)
# Out:
# Best parameters: {'kneighborsclassifier__n_neighbors': 5, 'meta_classifier__C': 0.1, 'randomforestclassifier__n_estimators': 50}
# Accuracy: 0.46

# %%
pred=grid.predict(Xtest)
print(classification_report(ytest, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.02      0.04       103
#            1       0.33      0.43      0.37       220
#            2       0.40      0.40      0.40       223
#            3       0.61      0.71      0.66       200
#
#     accuracy                           0.44       746
#    macro avg       0.46      0.39      0.37       746
# weighted avg       0.45      0.44      0.41       746

# %% [markdown]
# # Random forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier

rfc=RandomForestClassifier(random_state=42)
rfc.fit(Xtrain,ytrain)
# Out:
# RandomForestClassifier(random_state=42)

# %%
pred=model.predict(Xtest)
print(classification_report(ytest, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.27      0.50      0.35       103
#            1       0.42      0.21      0.28       220
#            2       0.52      0.24      0.33       223
#            3       0.45      0.76      0.56       200
#
#     accuracy                           0.41       746
#    macro avg       0.41      0.43      0.38       746
# weighted avg       0.44      0.41      0.38       746

# %% [markdown]
# ## Hyperparamter tunning of Random forest

# %%
param_grid = { 
    'n_estimators': [50,60,70,80,90,100],
    'max_depth' : [4,5,6,7,8]
}

# %%
best_rfc = GridSearchCV(estimator=rfc, param_grid=param_grid, cv= 3,n_jobs=-1)
best_rfc.fit(Xtrain,ytrain)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [4, 5, 6, 7, 8],
#                          'n_estimators': [50, 60, 70, 80, 90, 100]})

# %%
best_rfc.best_params_
# Out:
# {'max_depth': 4, 'n_estimators': 90}

# %%
random_forest=RandomForestClassifier(**best_rfc.best_params_)
random_forest.fit(Xtrain,ytrain)
# Out:
# RandomForestClassifier(max_depth=4, n_estimators=90)

# %%
pred=random_forest.predict(Xtest)
print(classification_report(ytest, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       103
#            1       0.41      0.41      0.41       220
#            2       0.51      0.48      0.50       223
#            3       0.56      0.89      0.69       200
#
#     accuracy                           0.50       746
#    macro avg       0.37      0.44      0.40       746
# weighted avg       0.42      0.50      0.45       746
